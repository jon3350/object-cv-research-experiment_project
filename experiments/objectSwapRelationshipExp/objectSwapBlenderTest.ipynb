# %% [markdown]
# # Set Up

# %%
import bpy
import bmesh
from mathutils.bvhtree import BVHTree
from mathutils import Vector
import os
import pandas as pd
import numpy as np
from bpy_extras.object_utils import world_to_camera_view
import json

# %%
#----------------------------------------------------------------------
# BLENDER STAPLES
def render_and_log(render_file_path):
    bpy.context.view_layer.update()
    bpy.context.scene.render.filepath = render_file_path
    bpy.ops.render.render(write_still = True)

def config_GPU_and_render_quality():
    # ──────────── Make sure GPU is used ─────────────
    # 3.1 Set render engine
    bpy.context.scene.render.engine = 'CYCLES'

    # 3.2 Configure Cycles backend
    prefs = bpy.context.preferences.addons["cycles"].preferences
    prefs.compute_device_type = "CUDA"   # or "OPTIX", "ONEAPI", "HIP"
    prefs.get_devices()                  # populate prefs.devices

    # 3.3 Enable all non-CPU devices
    for dev in prefs.devices:
        if dev.type != 'CPU':
            dev.use = True

    # 3.4 Tell the scene to use GPU
    bpy.context.scene.cycles.device = 'GPU'

    # ──────────── 4) Render settings ─────────────
    # 8192 standard but we will use 512 for testing
    # bpy.context.scene.cycles.samples            = 8192
    # bpy.context.scene.render.resolution_percentage = 100
    bpy.context.scene.cycles.samples            = 1024
    bpy.context.scene.render.resolution_percentage = 50
    # bpy.context.scene.cycles.samples            = 256
    # bpy.context.scene.render.resolution_percentage = 25
    # bpy.context.scene.cycles.samples            = 32
    # bpy.context.scene.render.resolution_percentage = 5

    # ──────────── 5) Print scene & device info ─────────────
    print("Scene name:", bpy.context.scene.name)
    print("Engine      :", bpy.context.scene.render.engine)
    print("Backend     :", prefs.compute_device_type)
    print("Scene device:", bpy.context.scene.cycles.device)
    print("Available devices:")
    for d in prefs.devices:
        print(f"  - {d.name:25} type={d.type:4} use={d.use}")
    # ──────────── Rest of code ─────────────
#----------------------------------------------------------------------

# %%
#----------------------------------------------------------------------
# MASTER_DICT
# get all the important information you need
# that does not require opening the blender file
def getMasterDict(dataset_path, scene_id):
    # Conversion_dicts
    # dicts to convert between object-indicies to solve_state_json_names and blender_names
    indexToBlender = {}
    blenderToIndex = {}
    jsonToBlender = {}
    blenderToJson = {}

    # get all object indecies from the objectsegmentation array
    # frames/ObjectSegmentation/camera_0/ObjectSegmentation_0_0_0048_0.npy
    obj_seg_path = os.path.join( dataset_path, scene_id, "frames", "ObjectSegmentation", "camera_0", "ObjectSegmentation_0_0_0048_0.npy")
    obj_seg_arr = np.load(obj_seg_path)
    obj_seg_set = set( obj_seg_arr.flatten() )
    if 0 in obj_seg_set:
        obj_seg_set.remove(0) # remove 0 from set

    # go through objects.json, find all matching objects, and update the conversion_dicts
    obj_json_path = os.path.join( dataset_path, scene_id, "frames", "Objects", "camera_0", "Objects_0_0_0048_0.json")
    with open( obj_json_path, "r") as obj_json_file:
        obj_json_map = json.load(obj_json_file)
    
    for key, meta in obj_json_map.items():
        blender_obj_name = key
        obj_index = meta["object_index"]
        if obj_index in obj_seg_set:
            indexToBlender[obj_index] = blender_obj_name
            blenderToIndex[blender_obj_name] = obj_index
    
    # print("PRE-FILTERING: Blender-Index Conversions: ", "Number of enteries: ", len(indexToBlender))
    # print("IndexToBlender: ", indexToBlender)
    # print("BlenderToIndex: ", blenderToIndex)
    # print("\n", flush = True)

    # filter out unwanted objects
    filtered_list = [] # a list of (obj, index) to be removed
    filter_set = {"kitchen_0", "living-room_0", "dining-room_0", "bedroom_0", "bathroom_0"}
    for blender_obj_name, obj_index in blenderToIndex.items():
        for filter_item in filter_set:
            if filter_item in blender_obj_name:
                filtered_list.append( (blender_obj_name, obj_index) )
                break

    for blender_obj_name, obj_index in filtered_list:
        blenderToIndex.pop(blender_obj_name)
        indexToBlender.pop(obj_index)

    # populate dicts for blender_obj_names to and from solve_state_json_obj_names
    solve_state_json_path = os.path.join( dataset_path, scene_id, "coarse", "solve_state.json" )
    with open(solve_state_json_path, "r") as solve_state_json_file:
        solve_state_json_map = json.load(solve_state_json_file)
        solve_state_json_map = solve_state_json_map["objs"] # unpack objs
    for key, meta in solve_state_json_map.items():
        if meta['obj'] in blenderToIndex:
            json_obj_name = key
            blender_obj_name = meta['obj']
            blenderToJson[blender_obj_name] = json_obj_name
            jsonToBlender[json_obj_name] = blender_obj_name
    # json has less objects than index and blender
    for obj_blender_name in blenderToIndex.keys():
        if obj_blender_name not in blenderToJson:
            blenderToJson[obj_blender_name] = None

    # print("Filter: ", "removedCount:", len(filtered_list), "remainingCount", len(blenderToIndex))
    # print("removed: ", filtered_list)
    # print("remaining: ", blenderToIndex.keys())
    # print("POST-FILTER: (index: blender : json)")
    # for obj_index, blender_obj_name in indexToBlender.items():
    #     print(f"{obj_index}: {blender_obj_name} : {blenderToJson[blender_obj_name]}")
    # print("\n", flush = True)


    # for each object (blender_name), map it to a list of 'dependents' that depend on it
    # i.e. table should map to all the plates on the table
    # use blender names for objects
    dependents_map = {}

    for root in blenderToIndex.keys():
        # run bfs
        queue = [ root ]
        dependents = set() # fill it with all objects connected to parent
        visited = { root } # technically not needed since you can only depend on one thing and there are no cycles
        while queue:
            # process current object by adding it to dependents set
            curr_obj_blender = queue.pop(0)
            if curr_obj_blender != root: # don't include the root as a dependent
                dependents.add( curr_obj_blender )

            # put all eligible children in the queue

            # Objects.json condition...
            # accept children of curr_obj_blender
            for child_index in obj_json_map[curr_obj_blender]["children"]:
                if child_index in indexToBlender and indexToBlender[child_index] not in visited:
                    visited.add( indexToBlender[child_index] )
                    queue.append( indexToBlender[child_index] )
            
            # Solve_state.json condition...
            if not blenderToJson[curr_obj_blender]: # some blender objs are not listed in obj
                continue
            for key in jsonToBlender.keys():
                if jsonToBlender[key] in visited:
                    continue
                for rel in solve_state_json_map[key]["relations"]:
                    target_name = rel["target_name"]
                    relation_type = rel["relation"]["relation_type"]
                    child_tags = rel["relation"]["child_tags"]
                    if (target_name == blenderToJson[curr_obj_blender]
                            and relation_type == "StableAgainst"
                            and "Subpart(bottom)" in child_tags
                    ):
                        visited.add( jsonToBlender[key] )
                        queue.append( jsonToBlender[key] )
        dependents_map[ root ] = dependents

    # print out pretty formatted dependents_map
    # def set_default(obj):
    #     if isinstance(obj, set):
    #         return list(obj)
    #     raise TypeError
    # pretty_print = json.dumps( dependents_map, indent=2, default=set_default )
    # print( "Dependents_map: ", pretty_print )

    # categorize objects by groups
    # create maps from groups to objects and vice versa
    groupToObjects = {}
    objectToGroup = {}
    for blender_obj_name in blenderToIndex.keys():
        index = blender_obj_name.find("Factory")
        if index != -1:
            group_name = blender_obj_name[:index]
        else:
            group_name = blender_obj_name
        objectToGroup[blender_obj_name] = group_name
        if group_name in groupToObjects:
            groupToObjects[group_name].append(blender_obj_name)
        else:
            groupToObjects[group_name] = [ blender_obj_name ]
    
    masterDict = {
        # our 4 name conversion dictionaries
        "indexToBlender": indexToBlender,
        "blenderToIndex": blenderToIndex,
        "jsonToBlender": jsonToBlender,
        "blenderToJson": blenderToJson,

        # relational dependencies
        "dependents_map": dependents_map,
        "groupToObjects": groupToObjects,
        "objectToGroup": objectToGroup,

        "obj_seg_arr": obj_seg_arr, #from objectSegmentation.npy
    }
    return masterDict
#----------------------------------------------------------------------

# %% [markdown]
# # Initial Testing

# %%
output_folder = "/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp/results" # for the data set of transformed images
dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94" # original dataset
index = 0

# read the pd as csv
df = pd.read_csv( "/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp/KitchenSpaceToOvenFiltered.csv" )

# for each row, extract the source, smallObject, and dest
row = df.loc[index]
source, smallObject, dest = row["source"], row["smallObject"], row["dest"]
scene_id = row["sceneId"]

# open blender scene
blender_scene_path = os.path.join( dataset_path, scene_id, "fine", "scene.blend" )
bpy.ops.wm.open_mainfile(filepath = blender_scene_path)
print(flush=True)
config_GPU_and_render_quality()
# Out:
# Read blend: "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94/1420624e/fine/scene.blend"
#
# Scene name: Scene
# Engine      : CYCLES
# Backend     : CUDA
# Scene device: GPU
# Available devices:
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - Intel Xeon Gold 5320 CPU @ 2.20GHz type=CPU  use=False
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True

# %%
img_name = "temp_img"
render_and_log( os.path.join( "/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp", img_name ) )
# Out:
# Fra:1 Mem:313.61M (Peak 313.61M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(4730346).spawn_asset(6552114)
# Fra:1 Mem:313.62M (Peak 313.62M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(2)
# Fra:1 Mem:313.62M (Peak 313.62M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(3)
# Fra:1 Mem:313.62M (Peak 313.62M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(5)
# Fra:1 Mem:313.65M (Peak 313.65M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(6)
# Fra:1 Mem:313.66M (Peak 313.66M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(7)
# Fra:1 Mem:313.67M (Peak 313.70M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(9)
# Fra:1 Mem:313.91M (Peak 313.91M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.wall
# Fra:1 Mem:314.07M (Peak 314.07M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.wall
# Fra:1 Mem:314.12M (Peak 314.13M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.floor
# Fra:1 Mem:314.21M (Peak 314.21M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.floor
# Fra:1 Mem:314.51M (Peak 314.55M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.floor
# Fra:1 Mem:314.67M (Peak 314.71M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.ceiling
# Fra:1 Mem:314.94M (Peak 314.94M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.ceiling
# Fra:1 Mem:314.99M (Peak 314.99M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.exterior
# Fra:1 Mem:315.01M (Peak 315.01M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.exterior
# Fra:1 Mem:315.08M (Peak 315.08M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | KitchenCabinetFactory(4096575).spawn_asset(397149)
# Fra:1 Mem:315.13M (Peak 315.13M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SimpleBookcaseFactory(7865613).spawn_asset(6067366)
# Fra:1 Mem:315.18M (Peak 315.18M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | LargePlantContainerFactory(3128120).spawn_asset(2241699)
# Fra:1 Mem:315.36M (Peak 315.36M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BeverageFridgeFactory(96617).spawn_asset(2208130)
# Fra:1 Mem:315.88M (Peak 315.88M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(8875617).spawn_asset(1194983)
# Fra:1 Mem:316.05M (Peak 316.05M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2965383).spawn_asset(2745444)
# Fra:1 Mem:316.32M (Peak 316.58M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BottleFactory(445526).spawn_asset(7773116)
# Fra:1 Mem:316.84M (Peak 316.84M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(4324530).spawn_asset(3234797)
# Fra:1 Mem:317.63M (Peak 317.70M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | JarFactory(9132780).spawn_asset(5002085)
# Fra:1 Mem:317.87M (Peak 317.87M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BookStackFactory(3677136).spawn_asset(891807)
# Fra:1 Mem:318.41M (Peak 318.44M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(8640907).spawn_asset(9289928)
# Fra:1 Mem:318.61M (Peak 318.60M) | Time:00:00.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | skirtingboard_support
# Fra:1 Mem:551.66M (Peak 585.74M) | Time:00:01.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:551.40M (Peak 585.74M) | Time:00:01.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.105
# Fra:1 Mem:551.40M (Peak 585.74M) | Time:00:01.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.030
# Fra:1 Mem:551.40M (Peak 585.74M) | Time:00:01.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.039
# Fra:1 Mem:551.40M (Peak 585.74M) | Time:00:01.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.084
# Fra:1 Mem:551.40M (Peak 585.74M) | Time:00:01.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.098
# Fra:1 Mem:553.23M (Peak 585.74M) | Time:00:01.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.103
# Fra:1 Mem:561.78M (Peak 602.43M) | Time:00:02.29 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:561.78M (Peak 602.43M) | Time:00:02.29 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:561.78M (Peak 602.43M) | Time:00:02.73 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:561.78M (Peak 602.43M) | Time:00:02.73 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:565.30M (Peak 602.43M) | Time:00:02.73 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:565.30M (Peak 602.43M) | Time:00:02.73 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:565.30M (Peak 602.43M) | Time:00:02.73 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:565.30M (Peak 602.43M) | Time:00:02.73 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:565.30M (Peak 602.43M) | Time:00:02.73 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:565.30M (Peak 602.43M) | Time:00:02.73 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:565.31M (Peak 602.43M) | Time:00:02.73 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:565.31M (Peak 602.43M) | Time:00:02.74 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:565.31M (Peak 602.43M) | Time:00:02.74 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:565.31M (Peak 602.43M) | Time:00:02.74 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:606.08M (Peak 606.08M) | Time:00:02.79 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:633.90M (Peak 633.90M) | Time:00:02.80 | Mem:51.85M, Peak:51.85M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:633.89M (Peak 633.90M) | Time:00:02.82 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Building BVH
# Fra:1 Mem:719.05M (Peak 719.05M) | Time:00:03.15 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH triangles and strands
# Fra:1 Mem:724.72M (Peak 724.72M) | Time:00:03.15 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH nodes
# Fra:1 Mem:678.11M (Peak 746.24M) | Time:00:03.26 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:678.12M (Peak 746.24M) | Time:00:03.26 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:745.84M (Peak 746.24M) | Time:00:03.56 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH 75%, duplicates 0%
# Fra:1 Mem:745.84M (Peak 746.24M) | Time:00:03.64 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:1 Mem:750.35M (Peak 750.35M) | Time:00:03.64 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:1 Mem:839.30M (Peak 839.30M) | Time:00:03.80 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:839.30M (Peak 839.30M) | Time:00:04.38 | Mem:160.25M, Peak:160.25M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:1 Mem:952.43M (Peak 952.43M) | Time:00:04.42 | Mem:160.25M, Peak:160.25M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:952.43M (Peak 952.43M) | Time:00:04.52 | Mem:273.37M, Peak:273.37M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:952.43M (Peak 952.43M) | Time:00:04.52 | Mem:273.38M, Peak:273.38M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:952.43M (Peak 952.43M) | Time:00:04.52 | Mem:273.38M, Peak:273.38M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:952.43M (Peak 952.43M) | Time:00:04.52 | Mem:273.38M, Peak:273.38M | Scene, ViewLayer | Updating Images | Loading sky_nishita
# Fra:1 Mem:953.43M (Peak 953.43M) | Time:00:04.53 | Mem:274.38M, Peak:274.38M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:953.43M (Peak 953.43M) | Time:00:04.53 | Mem:274.38M, Peak:274.38M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:953.43M (Peak 953.43M) | Time:00:04.53 | Mem:274.46M, Peak:274.46M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:953.43M (Peak 953.43M) | Time:00:04.53 | Mem:274.46M, Peak:274.46M | Scene, ViewLayer | Updating Lights | Importance map
# Fra:1 Mem:954.44M (Peak 958.93M) | Time:00:04.54 | Mem:275.46M, Peak:275.46M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:954.44M (Peak 958.93M) | Time:00:04.54 | Mem:275.46M, Peak:275.46M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:954.44M (Peak 958.93M) | Time:00:04.54 | Mem:275.46M, Peak:275.46M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:954.44M (Peak 958.93M) | Time:00:04.54 | Mem:275.38M, Peak:275.46M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:954.44M (Peak 958.93M) | Time:00:04.54 | Mem:275.47M, Peak:275.47M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:954.44M (Peak 958.93M) | Time:00:04.54 | Mem:275.47M, Peak:275.47M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:1061.88M (Peak 1061.88M) | Time:00:04.61 | Mem:275.47M, Peak:275.47M | Scene, ViewLayer | Sample 0/1024
# Fra:1 Mem:1069.80M (Peak 1069.80M) | Time:00:04.75 | Remaining:02:23.80 | Mem:275.47M, Peak:275.47M | Scene, ViewLayer | Sample 1/1024
# Fra:1 Mem:1069.84M (Peak 1077.71M) | Time:00:05.20 | Remaining:00:05.71 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 96/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:05.48 | Remaining:00:07.12 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 112/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:06.71 | Remaining:00:14.73 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 128/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:06.95 | Remaining:00:14.32 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 144/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:07.20 | Remaining:00:13.96 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 160/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:07.43 | Remaining:00:13.60 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 176/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:07.95 | Remaining:00:14.45 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 192/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:08.89 | Remaining:00:16.79 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 208/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:09.13 | Remaining:00:16.12 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 224/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:09.37 | Remaining:00:15.54 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 240/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:09.60 | Remaining:00:14.97 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 256/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:10.11 | Remaining:00:15.20 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 272/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:11.05 | Remaining:00:16.46 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 288/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:11.28 | Remaining:00:15.80 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 304/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:11.53 | Remaining:00:15.23 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 320/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:11.77 | Remaining:00:14.66 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 336/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:12.57 | Remaining:00:15.19 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 352/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:13.22 | Remaining:00:15.35 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 368/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:13.46 | Remaining:00:14.74 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 384/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:13.68 | Remaining:00:14.15 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 400/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:13.93 | Remaining:00:13.61 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 416/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:14.45 | Remaining:00:13.48 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 432/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:15.38 | Remaining:00:13.84 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 448/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:15.62 | Remaining:00:13.28 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 464/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:15.85 | Remaining:00:12.74 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 480/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:16.08 | Remaining:00:12.21 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 496/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:16.33 | Remaining:00:11.72 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 512/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:17.56 | Remaining:00:12.16 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 528/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:17.78 | Remaining:00:11.62 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 544/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:18.01 | Remaining:00:11.10 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 560/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:18.25 | Remaining:00:10.61 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 576/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:18.51 | Remaining:00:10.14 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 592/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:19.73 | Remaining:00:10.34 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 608/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:19.95 | Remaining:00:09.83 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 624/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:20.18 | Remaining:00:09.34 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 640/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:20.40 | Remaining:00:08.85 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 656/1024
# Fra:1 Mem:1069.84M (Peak 1077.75M) | Time:00:20.68 | Remaining:00:08.41 | Mem:275.47M, Peak:283.38M | Scene, ViewLayer | Sample 672/1024

# %%
def max_min_bound_box( obj, local = False ):
    for idx, corner in enumerate(obj.bound_box):
        if local:
            vec_corner = Vector(corner) # coordinates relative to object origin (obj.location)
        else:
            vec_corner = obj.matrix_world @ Vector(corner)
        if idx == 0:
            max_min_dict = {
                "x_max": vec_corner.x,
                "x_min": vec_corner.x,
                "y_max": vec_corner.y,
                "y_min": vec_corner.y,
                "z_max": vec_corner.z,
                "z_min": vec_corner.z
            }
        else:
            max_min_dict["x_max"] = max( max_min_dict["x_max"], vec_corner.x )
            max_min_dict["x_min"] = min( max_min_dict["x_min"], vec_corner.x )
            max_min_dict["y_max"] = max( max_min_dict["y_max"], vec_corner.y )
            max_min_dict["y_min"] = min( max_min_dict["y_min"], vec_corner.y )
            max_min_dict["z_max"] = max( max_min_dict["z_max"], vec_corner.z )
            max_min_dict["z_min"] = min( max_min_dict["z_min"], vec_corner.z )
    return max_min_dict

# %%
# move the plate (smallObject) right above the oven (dest)
small_obj = bpy.data.objects[smallObject]
small_obj_mmD = max_min_bound_box(small_obj)
small_obj_mmD_local = max_min_bound_box(small_obj, True)

print(small_obj_mmD)
print(small_obj_mmD_local)
print(small_obj.location) # location is prob already world coorindates
# print(small_obj.matrix_world @ small_obj.location) # this is prob wrong

print("All coordinates of bound box (World Coordinates)")
for corner in small_obj.bound_box:
    print( small_obj.matrix_world @ Vector(corner) )
print("All coordinates of bound box (Local Coordinates)")
for corner in small_obj.bound_box:
    print( Vector(corner) )
x_axis_world = small_obj.matrix_world.to_3x3() @ Vector((1, 0, 0))
y_axis_world = small_obj.matrix_world.to_3x3() @ Vector((0, 1, 0))
z_axis_world = small_obj.matrix_world.to_3x3() @ Vector((0, 0, 1))
print(x_axis_world, y_axis_world, z_axis_world)
# Out:
# {'x_max': 7.772401332855225, 'x_min': 7.152478218078613, 'y_max': 5.932343482971191, 'y_min': 5.172405242919922, 'z_max': 1.4259662628173828, 'z_min': 1.0524342060089111}
# {'x_max': 0.6199231743812561, 'x_min': 0.0, 'y_max': 0.7599380016326904, 'y_min': 0.0, 'z_max': 0.3735320568084717, 'z_min': -2.7755575615628914e-17}
# <Vector (7.7724, 5.9323, 1.0524)>
# All coordinates of bound box (World Coordinates)
# <Vector (7.7724, 5.9323, 1.0524)>
# <Vector (7.7724, 5.9323, 1.4260)>
# <Vector (7.7724, 5.1724, 1.4260)>
# <Vector (7.7724, 5.1724, 1.0524)>
# <Vector (7.1525, 5.9323, 1.0524)>
# <Vector (7.1525, 5.9323, 1.4260)>
# <Vector (7.1525, 5.1724, 1.4260)>
# <Vector (7.1525, 5.1724, 1.0524)>
# All coordinates of bound box (Local Coordinates)
# <Vector (0.0000, 0.0000, -0.0000)>
# <Vector (0.0000, 0.0000, 0.3735)>
# <Vector (0.0000, 0.7599, 0.3735)>
# <Vector (0.0000, 0.7599, -0.0000)>
# <Vector (0.6199, 0.0000, -0.0000)>
# <Vector (0.6199, 0.0000, 0.3735)>
# <Vector (0.6199, 0.7599, 0.3735)>
# <Vector (0.6199, 0.7599, -0.0000)>
# <Vector (-1.0000, -0.0000, 0.0000)> <Vector (0.0000, -1.0000, 0.0000)> <Vector (0.0000, 0.0000, 1.0000)>

# %%
big_obj = bpy.data.objects[dest]
big_obj_mmD = max_min_bound_box( big_obj )
big_obj_mmD_local = max_min_bound_box( big_obj, True )

print(big_obj_mmD)
print(big_obj_mmD_local)
print(big_obj.location) # location is prob already world coorindates
print(big_obj.matrix_world @ big_obj.location) # this seems wrong
# Out:
# {'x_max': 5.724734306335449, 'x_min': 4.621462821960449, 'y_max': 6.4947099685668945, 'y_min': 5.17918586730957, 'z_max': 1.4444997310638428, 'z_min': 0.10759860277175903}
# {'x_max': 1.258986234664917, 'x_min': -0.05653773248195648, 'y_max': 1.1032711267471313, 'y_min': 0.0, 'z_max': 1.3369011878967285, 'z_min': 0.0}
# <Vector (5.7247, 5.2357, 0.1076)>
# <Vector (0.4890, 10.9605, 0.2152)>

# %%
# align center of small_obj with big_obj for the x,y dimensions

# get center of small_obj x,y
small_obj_cx = (small_obj_mmD["x_min"] + small_obj_mmD["x_max"]) / 2
small_obj_cy = (small_obj_mmD["y_min"] + small_obj_mmD["y_max"]) / 2

# get center of big_obj x,y
big_obj_cx = (big_obj_mmD["x_min"] + big_obj_mmD["x_max"]) / 2
big_obj_cy = (big_obj_mmD["y_min"] + big_obj_mmD["y_max"]) / 2

# calculate displacement
disp_x = big_obj_cx - small_obj_cx
disp_y = big_obj_cy - small_obj_cy


# get bottom of small_obj to line up with top of big_obj
disp_z = big_obj_mmD["z_max"] - small_obj_mmD["z_min"]
print(disp_z)

# move small object origin
small_obj.location += Vector((disp_x, disp_y, disp_z))
# Out:
# 0.39206552505493164

# %%
img_name = "temp_img"
render_and_log( os.path.join( "/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp", img_name ) )
# Out:
# Fra:1 Mem:304.20M (Peak 304.20M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(4730346).spawn_asset(6552114)
# Fra:1 Mem:304.21M (Peak 304.21M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(2)
# Fra:1 Mem:304.21M (Peak 304.21M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(3)
# Fra:1 Mem:304.23M (Peak 304.23M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(4)
# Fra:1 Mem:305.25M (Peak 306.26M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(5)
# Fra:1 Mem:306.27M (Peak 306.27M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(7)
# Fra:1 Mem:306.50M (Peak 306.50M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(8)
# Fra:1 Mem:306.59M (Peak 306.64M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(9)
# Fra:1 Mem:306.72M (Peak 306.72M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(10)
# Fra:1 Mem:306.86M (Peak 306.86M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.wall
# Fra:1 Mem:307.03M (Peak 307.03M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.floor
# Fra:1 Mem:307.02M (Peak 307.07M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.floor
# Fra:1 Mem:307.47M (Peak 307.47M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.floor
# Fra:1 Mem:307.52M (Peak 307.52M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.ceiling
# Fra:1 Mem:307.65M (Peak 307.65M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.ceiling
# Fra:1 Mem:307.78M (Peak 307.78M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.exterior
# Fra:1 Mem:307.79M (Peak 307.79M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.exterior
# Fra:1 Mem:307.79M (Peak 307.79M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.exterior
# Fra:1 Mem:308.12M (Peak 308.14M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SimpleBookcaseFactory(2630571).spawn_asset(6524038)
# Fra:1 Mem:308.21M (Peak 308.21M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SimpleBookcaseFactory(7865613).spawn_asset(6067366)
# Fra:1 Mem:308.27M (Peak 308.27M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | OvenFactory(2033892).spawn_asset(8574077)
# Fra:1 Mem:308.58M (Peak 308.58M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | KitchenSpaceFactory(513529).spawn_asset(9976799)
# Fra:1 Mem:308.60M (Peak 308.61M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BeverageFridgeFactory(96617).spawn_asset(2208130)
# Fra:1 Mem:308.82M (Peak 308.82M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WallArtFactory(1210002).spawn_asset(539140)
# Fra:1 Mem:308.93M (Peak 308.93M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(8875617).spawn_asset(1194983)
# Fra:1 Mem:309.04M (Peak 309.04M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2965383).spawn_asset(2745444)
# Fra:1 Mem:309.09M (Peak 309.09M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | NatureShelfTrinketsFactory(2825353).spawn_asset(8069978)
# Fra:1 Mem:309.20M (Peak 309.20M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BottleFactory(445526).spawn_asset(7773116)
# Fra:1 Mem:309.57M (Peak 309.62M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | MicrowaveFactory(1849906).spawn_asset(842634)
# Fra:1 Mem:309.84M (Peak 309.84M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(4324530).spawn_asset(3234797)
# Fra:1 Mem:310.06M (Peak 310.07M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BookStackFactory(2491329).spawn_asset(8152350)
# Fra:1 Mem:310.17M (Peak 310.17M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | JarFactory(9132780).spawn_asset(5002085)
# Fra:1 Mem:310.20M (Peak 310.20M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BookStackFactory(3677136).spawn_asset(891807)
# Fra:1 Mem:310.25M (Peak 310.29M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(9833609).spawn_asset(5185903)
# Fra:1 Mem:310.43M (Peak 310.44M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(5055643).spawn_asset(4852438)
# Fra:1 Mem:310.78M (Peak 310.79M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(8640907).spawn_asset(9289928)
# Fra:1 Mem:310.81M (Peak 310.81M) | Time:00:02.21 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | skirtingboard_support
# Fra:1 Mem:544.26M (Peak 580.82M) | Time:00:02.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:543.99M (Peak 580.82M) | Time:00:02.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.105
# Fra:1 Mem:543.99M (Peak 580.82M) | Time:00:02.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.025
# Fra:1 Mem:543.99M (Peak 580.82M) | Time:00:02.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.028
# Fra:1 Mem:543.99M (Peak 580.82M) | Time:00:02.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.072
# Fra:1 Mem:543.99M (Peak 580.82M) | Time:00:02.35 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.087
# Fra:1 Mem:554.36M (Peak 594.16M) | Time:00:02.51 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:554.36M (Peak 594.16M) | Time:00:02.51 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:554.36M (Peak 594.16M) | Time:00:04.20 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:554.36M (Peak 594.16M) | Time:00:04.20 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:557.87M (Peak 594.16M) | Time:00:04.20 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:557.87M (Peak 594.16M) | Time:00:04.20 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:557.87M (Peak 594.16M) | Time:00:04.20 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:557.87M (Peak 594.16M) | Time:00:04.20 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:557.87M (Peak 594.16M) | Time:00:04.20 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:557.87M (Peak 594.16M) | Time:00:04.20 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:557.89M (Peak 594.16M) | Time:00:04.20 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:557.89M (Peak 594.16M) | Time:00:04.21 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:557.89M (Peak 594.16M) | Time:00:04.21 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:557.89M (Peak 594.16M) | Time:00:04.21 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:598.65M (Peak 598.65M) | Time:00:04.27 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:626.48M (Peak 626.48M) | Time:00:04.29 | Mem:51.85M, Peak:51.85M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:626.47M (Peak 626.48M) | Time:00:04.31 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Building BVH
# Fra:1 Mem:711.62M (Peak 711.62M) | Time:00:04.63 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Building BVH 96%, duplicates 0%
# Fra:1 Mem:711.62M (Peak 711.62M) | Time:00:04.64 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH triangles and strands
# Fra:1 Mem:717.30M (Peak 717.30M) | Time:00:04.65 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH nodes
# Fra:1 Mem:670.69M (Peak 738.81M) | Time:00:04.75 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:670.69M (Peak 738.81M) | Time:00:04.75 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:738.41M (Peak 738.81M) | Time:00:05.06 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH 74%, duplicates 0%
# Fra:1 Mem:738.41M (Peak 738.81M) | Time:00:05.14 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:1 Mem:742.92M (Peak 742.92M) | Time:00:05.15 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:1 Mem:831.85M (Peak 831.85M) | Time:00:05.33 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:831.85M (Peak 831.85M) | Time:00:05.95 | Mem:160.23M, Peak:160.23M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:1 Mem:944.98M (Peak 944.98M) | Time:00:06.01 | Mem:160.23M, Peak:160.23M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:944.98M (Peak 944.98M) | Time:00:06.09 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:944.98M (Peak 944.98M) | Time:00:06.09 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:944.98M (Peak 944.98M) | Time:00:06.09 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:944.98M (Peak 944.98M) | Time:00:06.09 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Images | Loading sky_nishita
# Fra:1 Mem:945.98M (Peak 945.98M) | Time:00:06.10 | Mem:274.36M, Peak:274.36M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:945.98M (Peak 945.98M) | Time:00:06.10 | Mem:274.36M, Peak:274.36M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:945.98M (Peak 945.98M) | Time:00:06.10 | Mem:274.44M, Peak:274.44M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:945.98M (Peak 945.98M) | Time:00:06.11 | Mem:274.45M, Peak:274.45M | Scene, ViewLayer | Updating Lights | Importance map
# Fra:1 Mem:946.98M (Peak 951.48M) | Time:00:06.11 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:946.98M (Peak 951.48M) | Time:00:06.11 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:946.98M (Peak 951.48M) | Time:00:06.11 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:946.99M (Peak 951.48M) | Time:00:06.11 | Mem:275.37M, Peak:275.45M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:946.99M (Peak 951.48M) | Time:00:06.11 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:946.99M (Peak 951.48M) | Time:00:06.11 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:1054.43M (Peak 1054.43M) | Time:00:06.18 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Sample 0/1024
# Fra:1 Mem:1062.35M (Peak 1062.35M) | Time:00:06.32 | Remaining:02:26.89 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Sample 1/1024
# Fra:1 Mem:1062.39M (Peak 1070.26M) | Time:00:06.79 | Remaining:00:05.86 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 96/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:07.06 | Remaining:00:07.17 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 112/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:08.28 | Remaining:00:14.71 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 128/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:08.51 | Remaining:00:14.26 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 144/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:08.75 | Remaining:00:13.86 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 160/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:08.98 | Remaining:00:13.50 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 176/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:09.24 | Remaining:00:13.23 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 192/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:10.47 | Remaining:00:16.82 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 208/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:10.68 | Remaining:00:16.06 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 224/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:10.89 | Remaining:00:15.39 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 240/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:11.12 | Remaining:00:14.81 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 256/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:11.40 | Remaining:00:14.43 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 272/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:12.63 | Remaining:00:16.48 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 288/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:12.85 | Remaining:00:15.79 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 304/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:13.06 | Remaining:00:15.13 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 320/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:13.30 | Remaining:00:14.58 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 336/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:13.58 | Remaining:00:14.12 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 352/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:14.81 | Remaining:00:15.39 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 368/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:15.05 | Remaining:00:14.78 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 384/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:15.28 | Remaining:00:14.20 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 400/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:15.49 | Remaining:00:13.61 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 416/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:15.75 | Remaining:00:13.11 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 432/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:16.96 | Remaining:00:13.86 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 448/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:17.18 | Remaining:00:13.27 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 464/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:17.39 | Remaining:00:12.69 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 480/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:17.61 | Remaining:00:12.16 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 496/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:17.92 | Remaining:00:11.73 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 512/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:19.13 | Remaining:00:12.16 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 528/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:19.35 | Remaining:00:11.61 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 544/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:19.56 | Remaining:00:11.08 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 560/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:19.78 | Remaining:00:10.57 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 576/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:20.09 | Remaining:00:10.15 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 592/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:21.31 | Remaining:00:10.35 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 608/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:21.52 | Remaining:00:09.83 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 624/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:21.74 | Remaining:00:09.33 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 640/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:21.95 | Remaining:00:08.84 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 656/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:22.27 | Remaining:00:08.42 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 672/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:23.47 | Remaining:00:08.44 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 688/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:23.69 | Remaining:00:07.96 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 704/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:23.90 | Remaining:00:07.48 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 720/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:24.11 | Remaining:00:07.01 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 736/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:24.44 | Remaining:00:06.60 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 752/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:25.29 | Remaining:00:06.37 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 768/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:25.66 | Remaining:00:05.96 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 784/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:25.87 | Remaining:00:05.51 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 800/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:26.09 | Remaining:00:05.07 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 816/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:26.31 | Remaining:00:04.64 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 832/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:26.90 | Remaining:00:04.29 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 848/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:27.68 | Remaining:00:03.98 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 864/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:27.89 | Remaining:00:03.55 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 880/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:28.11 | Remaining:00:03.13 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 896/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:28.32 | Remaining:00:02.71 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 912/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:28.54 | Remaining:00:02.31 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 928/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:28.79 | Remaining:00:01.91 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 944/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:29.65 | Remaining:00:01.56 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 960/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:29.86 | Remaining:00:01.16 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 976/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:30.08 | Remaining:00:00.77 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 992/1024
# Fra:1 Mem:1062.39M (Peak 1070.30M) | Time:00:30.29 | Remaining:00:00.38 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 1008/1024
# Fra:1 Mem:1065.90M (Peak 1072.93M) | Time:00:30.50 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 1024/1024
# Fra:1 Mem:1065.90M (Peak 1072.93M) | Time:00:30.50 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Finished
# Saved: '/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp/temp_img.png'
# Time: 00:32.79 (Saving: 00:00.11)

# %%
def add_rigid_body( obj, is_active ):
    # select object
    bpy.ops.object.select_all(action = "DESELECT")
    obj.select_set(True)
    bpy.context.view_layer.objects.active = obj
    
    bpy.ops.rigidbody.object_add()
    if is_active:
        obj.rigid_body.type = 'ACTIVE'
    else:
        obj.rigid_body.type = 'PASSIVE'

    # Optional: Set collision shape
    obj.rigid_body.collision_shape = 'CONVEX_HULL'

# %%
# https://blender.stackexchange.com/questions/71289/using-overlap-to-check-if-two-meshes-are-intersecting
def get_BVH_tree(obj):
    depsgraph = bpy.context.evaluated_depsgraph_get()
    eval_obj = obj.evaluated_get(depsgraph)
    mesh = eval_obj.to_mesh()

    bm = bmesh.new()
    bm.from_mesh(mesh)
    bm.transform(eval_obj.matrix_world)

    tree = BVHTree.FromBMesh(bm)

    bm.free()
    eval_obj.to_mesh_clear()
    return tree

# #get intersecting pairs
# inter = obj_now_BVHtree.overlap(obj_next_BVHtree)

# #if list is empty, no objects are touching
# if inter != []:
#     print(obj_now + " and " + obj_next + " are touching!")
# else:
#     print(obj_now + " and " + obj_next + " NOT touching!")

# %%
bpy.context.scene.frame_set(1)

# give small obj a rigid body
# give large object a rigid body, set to passive
add_rigid_body(small_obj, is_active=True)
add_rigid_body(big_obj, is_active=False)

# go to frame 20
for frame in range(1, 16):
    bpy.context.scene.frame_set(frame)
    bpy.context.view_layer.update()  # Ensure updates are processed

    # render image
    # img_name = f"temp_img{frame}"
    # render_and_log( os.path.join( "/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp", img_name ) )

    # add bmesh and get BVH tree for both objects
    small_tree = get_BVH_tree(small_obj)
    big_tree = get_BVH_tree(big_obj)
    inter = big_tree.overlap(small_tree)
    if inter:
        print(f"Collision at Frame {frame}")
        break
# Out:
# Fra:1 Mem:312.67M (Peak 312.67M) | Time:00:00.96 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(4730346).spawn_asset(6552114)
# Fra:1 Mem:312.67M (Peak 312.67M) | Time:00:00.96 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(4730346).spawn_asset(20988)
# Fra:1 Mem:312.67M (Peak 312.67M) | Time:00:00.96 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(4730346).spawn_asset(947399)
# Fra:1 Mem:314.69M (Peak 314.70M) | Time:00:00.96 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | TapFactory(9203000).spawn_asset(807853)
# Fra:1 Mem:314.71M (Peak 314.71M) | Time:00:00.96 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | LiteDoorFactory(5220690).spawn_asset(1)
# Fra:1 Mem:314.72M (Peak 314.72M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | PanelDoorFactory(1505269).spawn_asset(3)
# Fra:1 Mem:314.78M (Peak 314.78M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | GlassPanelDoorFactory(6323250).spawn_asset(0)
# Fra:1 Mem:314.90M (Peak 314.90M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | GlassPanelDoorFactory(6323250).spawn_asset(4)
# Fra:1 Mem:315.20M (Peak 315.20M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(2)
# Fra:1 Mem:315.35M (Peak 315.35M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(4)
# Fra:1 Mem:315.44M (Peak 315.44M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(5)
# Fra:1 Mem:315.52M (Peak 315.54M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(6)
# Fra:1 Mem:315.71M (Peak 315.74M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(8)
# Fra:1 Mem:315.84M (Peak 315.87M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(9)
# Fra:1 Mem:316.07M (Peak 316.07M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.wall
# Fra:1 Mem:316.44M (Peak 316.45M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.wall
# Fra:1 Mem:316.53M (Peak 316.53M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.wall
# Fra:1 Mem:316.66M (Peak 316.66M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.wall
# Fra:1 Mem:316.73M (Peak 316.73M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.floor
# Fra:1 Mem:316.79M (Peak 316.81M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.floor
# Fra:1 Mem:317.22M (Peak 317.22M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.floor
# Fra:1 Mem:317.52M (Peak 317.52M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.ceiling
# Fra:1 Mem:317.62M (Peak 317.69M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.ceiling
# Fra:1 Mem:318.30M (Peak 318.31M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.ceiling
# Fra:1 Mem:318.28M (Peak 318.31M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.exterior
# Fra:1 Mem:318.66M (Peak 318.65M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SimpleBookcaseFactory(2630571).spawn_asset(6524038)
# Fra:1 Mem:318.72M (Peak 318.73M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | KitchenCabinetFactory(4096575).spawn_asset(397149)
# Fra:1 Mem:318.82M (Peak 318.82M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | OvenFactory(2033892).spawn_asset(8574077)
# Fra:1 Mem:319.19M (Peak 319.19M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | KitchenSpaceFactory(513529).spawn_asset(9976799)
# Fra:1 Mem:319.70M (Peak 319.70M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BeverageFridgeFactory(96617).spawn_asset(2208130)
# Fra:1 Mem:320.29M (Peak 320.29M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WallArtFactory(3906066).spawn_asset(5796891)
# Fra:1 Mem:320.37M (Peak 320.37M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(8875617).spawn_asset(1194983)
# Fra:1 Mem:320.44M (Peak 320.44M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2264099).spawn_asset(4874523)
# Fra:1 Mem:320.70M (Peak 320.70M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2965383).spawn_asset(2745444)
# Fra:1 Mem:320.89M (Peak 320.91M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BottleFactory(445526).spawn_asset(7773116)
# Fra:1 Mem:320.83M (Peak 320.91M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | JarFactory(4380497).spawn_asset(6313724)
# Fra:1 Mem:321.40M (Peak 321.46M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(4324530).spawn_asset(3234797)
# Fra:1 Mem:321.50M (Peak 321.50M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | JarFactory(9132780).spawn_asset(5002085)
# Fra:1 Mem:321.66M (Peak 322.84M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BookStackFactory(3677136).spawn_asset(891807)
# Fra:1 Mem:324.47M (Peak 324.47M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(9833609).spawn_asset(5185903)
# Fra:1 Mem:325.67M (Peak 325.83M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | skirtingboard_support
# Fra:1 Mem:326.40M (Peak 326.40M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(5055643).spawn_asset(4852438)
# Fra:1 Mem:326.65M (Peak 326.65M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBagFactory(2438897).spawn_asset(3764059)
# Fra:1 Mem:326.79M (Peak 326.80M) | Time:00:00.97 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(8640907).spawn_asset(9289928)
# Fra:1 Mem:552.37M (Peak 599.68M) | Time:00:01.17 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:552.11M (Peak 599.68M) | Time:00:01.17 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.105
# Fra:1 Mem:552.11M (Peak 599.68M) | Time:00:01.17 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.027
# Fra:1 Mem:552.11M (Peak 599.68M) | Time:00:01.17 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.031
# Fra:1 Mem:552.11M (Peak 599.68M) | Time:00:01.17 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.059
# Fra:1 Mem:552.11M (Peak 599.68M) | Time:00:01.17 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.095
# Fra:1 Mem:552.11M (Peak 599.68M) | Time:00:01.17 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.103
# Fra:1 Mem:562.44M (Peak 602.48M) | Time:00:02.20 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:562.44M (Peak 602.48M) | Time:00:02.20 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:562.44M (Peak 602.48M) | Time:00:02.69 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:562.44M (Peak 602.48M) | Time:00:02.69 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:565.96M (Peak 602.48M) | Time:00:02.70 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:565.96M (Peak 602.48M) | Time:00:02.70 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:565.96M (Peak 602.48M) | Time:00:02.70 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:565.96M (Peak 602.48M) | Time:00:02.70 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:565.96M (Peak 602.48M) | Time:00:02.70 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:565.96M (Peak 602.48M) | Time:00:02.70 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:565.97M (Peak 602.48M) | Time:00:02.70 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:565.97M (Peak 602.48M) | Time:00:02.70 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:565.97M (Peak 602.48M) | Time:00:02.70 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:565.97M (Peak 602.48M) | Time:00:02.70 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:606.74M (Peak 606.74M) | Time:00:02.76 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:634.56M (Peak 634.56M) | Time:00:02.77 | Mem:51.85M, Peak:51.85M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:634.55M (Peak 634.56M) | Time:00:02.79 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Building BVH
# Fra:1 Mem:719.71M (Peak 719.71M) | Time:00:03.10 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH triangles and strands
# Fra:1 Mem:725.38M (Peak 725.38M) | Time:00:03.10 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH nodes
# Fra:1 Mem:678.78M (Peak 746.90M) | Time:00:03.20 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:678.78M (Peak 746.90M) | Time:00:03.20 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:746.50M (Peak 746.90M) | Time:00:03.50 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH 73%, duplicates 0%
# Fra:1 Mem:746.50M (Peak 746.90M) | Time:00:03.59 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:1 Mem:751.01M (Peak 751.01M) | Time:00:03.59 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:1 Mem:839.94M (Peak 839.94M) | Time:00:03.75 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:839.94M (Peak 839.94M) | Time:00:04.28 | Mem:160.23M, Peak:160.23M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:1 Mem:953.06M (Peak 953.06M) | Time:00:04.34 | Mem:160.23M, Peak:160.23M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:953.06M (Peak 953.06M) | Time:00:04.43 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:953.06M (Peak 953.06M) | Time:00:04.43 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:953.06M (Peak 953.06M) | Time:00:04.43 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:953.06M (Peak 953.06M) | Time:00:04.43 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Images | Loading sky_nishita
# Fra:1 Mem:954.06M (Peak 954.06M) | Time:00:04.44 | Mem:274.36M, Peak:274.36M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:954.06M (Peak 954.06M) | Time:00:04.44 | Mem:274.36M, Peak:274.36M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:954.06M (Peak 954.06M) | Time:00:04.44 | Mem:274.44M, Peak:274.44M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:954.07M (Peak 954.07M) | Time:00:04.44 | Mem:274.45M, Peak:274.45M | Scene, ViewLayer | Updating Lights | Importance map
# Fra:1 Mem:955.07M (Peak 959.57M) | Time:00:04.45 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:955.07M (Peak 959.57M) | Time:00:04.45 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:955.07M (Peak 959.57M) | Time:00:04.45 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:955.07M (Peak 959.57M) | Time:00:04.45 | Mem:275.37M, Peak:275.45M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:955.07M (Peak 959.57M) | Time:00:04.45 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:955.07M (Peak 959.57M) | Time:00:04.45 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:1062.51M (Peak 1062.51M) | Time:00:04.52 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Sample 0/1024
# Fra:1 Mem:1070.43M (Peak 1070.43M) | Time:00:04.66 | Remaining:02:26.20 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Sample 1/1024
# Fra:1 Mem:1070.47M (Peak 1078.34M) | Time:00:05.12 | Remaining:00:05.85 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 96/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:05.39 | Remaining:00:07.12 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 112/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:06.61 | Remaining:00:14.61 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 128/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:06.84 | Remaining:00:14.17 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 144/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:07.07 | Remaining:00:13.78 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 160/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:07.31 | Remaining:00:13.44 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 176/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:07.57 | Remaining:00:13.21 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 192/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:08.80 | Remaining:00:16.80 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 208/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:09.01 | Remaining:00:16.03 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 224/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:09.22 | Remaining:00:15.36 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 240/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:09.44 | Remaining:00:14.76 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 256/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:10.31 | Remaining:00:16.00 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 272/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:10.96 | Remaining:00:16.45 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 288/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:11.17 | Remaining:00:15.74 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 304/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:11.38 | Remaining:00:15.09 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 320/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:11.62 | Remaining:00:14.54 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 336/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:11.90 | Remaining:00:14.08 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 352/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:13.14 | Remaining:00:15.36 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 368/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:13.37 | Remaining:00:14.75 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 384/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:13.61 | Remaining:00:14.17 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 400/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:13.82 | Remaining:00:13.59 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 416/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:14.07 | Remaining:00:13.09 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 432/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:15.29 | Remaining:00:13.84 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 448/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:15.51 | Remaining:00:13.26 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 464/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:15.72 | Remaining:00:12.69 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 480/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:15.94 | Remaining:00:12.15 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 496/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:16.24 | Remaining:00:11.72 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 512/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:17.45 | Remaining:00:12.14 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 528/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:17.66 | Remaining:00:11.59 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 544/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:17.88 | Remaining:00:11.07 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 560/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:18.10 | Remaining:00:10.56 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 576/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:18.42 | Remaining:00:10.14 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 592/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:19.63 | Remaining:00:10.34 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 608/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:19.84 | Remaining:00:09.82 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 624/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:20.06 | Remaining:00:09.32 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 640/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:20.28 | Remaining:00:08.83 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 656/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:20.59 | Remaining:00:08.41 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 672/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:21.81 | Remaining:00:08.44 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 688/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:22.03 | Remaining:00:07.95 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 704/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:22.24 | Remaining:00:07.48 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 720/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:22.45 | Remaining:00:07.01 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 736/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:22.91 | Remaining:00:06.65 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 752/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:23.83 | Remaining:00:06.43 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 768/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:24.05 | Remaining:00:05.97 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 784/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:24.26 | Remaining:00:05.52 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 800/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:24.48 | Remaining:00:05.08 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 816/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:24.70 | Remaining:00:04.65 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 832/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:24.94 | Remaining:00:04.23 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 848/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:25.95 | Remaining:00:03.96 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 864/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:26.17 | Remaining:00:03.54 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 880/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:26.40 | Remaining:00:03.12 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 896/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:26.60 | Remaining:00:02.71 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 912/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:26.82 | Remaining:00:02.30 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 928/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:27.13 | Remaining:00:01.91 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 944/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:27.99 | Remaining:00:01.56 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 960/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:28.35 | Remaining:00:01.17 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 976/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:28.56 | Remaining:00:00.77 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 992/1024
# Fra:1 Mem:1070.47M (Peak 1078.38M) | Time:00:28.77 | Remaining:00:00.38 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 1008/1024
# Fra:1 Mem:1073.99M (Peak 1081.02M) | Time:00:28.98 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 1024/1024
# Fra:1 Mem:1073.99M (Peak 1081.02M) | Time:00:28.98 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Finished
# Saved: '/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp/temp_img1.png'
# Time: 00:31.27 (Saving: 00:00.11)
#
# Fra:2 Mem:410.66M (Peak 410.66M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(4730346).spawn_asset(6552114)
# Fra:2 Mem:410.66M (Peak 410.66M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | TapFactory(9203000).spawn_asset(807853)
# Fra:2 Mem:410.66M (Peak 410.66M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | LiteDoorFactory(5220690).spawn_asset(1)
# Fra:2 Mem:410.67M (Peak 410.67M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | PanelDoorFactory(1505269).spawn_asset(3)
# Fra:2 Mem:410.70M (Peak 410.70M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | GlassPanelDoorFactory(6323250).spawn_asset(0)
# Fra:2 Mem:410.85M (Peak 410.85M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(0)
# Fra:2 Mem:410.87M (Peak 410.87M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(1)
# Fra:2 Mem:410.96M (Peak 410.96M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(3)
# Fra:2 Mem:411.08M (Peak 411.08M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(4)
# Fra:2 Mem:411.14M (Peak 411.14M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(5)
# Fra:2 Mem:411.14M (Peak 411.14M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(6)
# Fra:2 Mem:411.21M (Peak 411.25M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(7)
# Fra:2 Mem:411.65M (Peak 411.65M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(8)
# Fra:2 Mem:412.07M (Peak 412.07M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(9)
# Fra:2 Mem:412.18M (Peak 412.18M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.wall
# Fra:2 Mem:412.53M (Peak 412.57M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.wall
# Fra:2 Mem:412.77M (Peak 412.77M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.wall
# Fra:2 Mem:412.82M (Peak 412.82M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.floor
# Fra:2 Mem:412.96M (Peak 412.96M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.floor
# Fra:2 Mem:413.14M (Peak 413.15M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.floor
# Fra:2 Mem:413.33M (Peak 413.33M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.ceiling
# Fra:2 Mem:413.47M (Peak 413.47M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.ceiling
# Fra:2 Mem:413.42M (Peak 413.47M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.exterior
# Fra:2 Mem:414.44M (Peak 414.44M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.exterior
# Fra:2 Mem:414.48M (Peak 414.48M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.exterior
# Fra:2 Mem:414.59M (Peak 414.65M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SimpleBookcaseFactory(2630571).spawn_asset(6524038)
# Fra:2 Mem:414.78M (Peak 414.78M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | KitchenCabinetFactory(4096575).spawn_asset(397149)
# Fra:2 Mem:414.84M (Peak 414.95M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | OvenFactory(2033892).spawn_asset(8574077)
# Fra:2 Mem:414.96M (Peak 414.96M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | LargePlantContainerFactory(3128120).spawn_asset(2241699)
# Fra:2 Mem:415.04M (Peak 415.04M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BeverageFridgeFactory(96617).spawn_asset(2208130)
# Fra:2 Mem:415.08M (Peak 415.08M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WallArtFactory(1210002).spawn_asset(539140)
# Fra:2 Mem:415.12M (Peak 416.25M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(8875617).spawn_asset(1194983)
# Fra:2 Mem:416.32M (Peak 416.32M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2965383).spawn_asset(2745444)
# Fra:2 Mem:416.33M (Peak 416.33M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BottleFactory(445526).spawn_asset(7773116)
# Fra:2 Mem:416.43M (Peak 416.42M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | JarFactory(4380497).spawn_asset(6313724)
# Fra:2 Mem:416.57M (Peak 416.57M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(4324530).spawn_asset(3234797)
# Fra:2 Mem:416.59M (Peak 416.59M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BookStackFactory(2491329).spawn_asset(8152350)
# Fra:2 Mem:416.74M (Peak 416.81M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | JarFactory(9132780).spawn_asset(5002085)
# Fra:2 Mem:416.89M (Peak 416.90M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BookStackFactory(3677136).spawn_asset(891807)
# Fra:2 Mem:416.90M (Peak 416.90M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(5055643).spawn_asset(4852438)
# Fra:2 Mem:416.92M (Peak 416.92M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBagFactory(2438897).spawn_asset(3764059)
# Fra:2 Mem:416.99M (Peak 416.99M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | skirtingboard_support
# Fra:2 Mem:552.37M (Peak 591.21M) | Time:00:02.07 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:2 Mem:552.11M (Peak 591.21M) | Time:00:02.07 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.104
# Fra:2 Mem:552.11M (Peak 591.21M) | Time:00:02.07 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.025
# Fra:2 Mem:552.11M (Peak 591.21M) | Time:00:02.07 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.050
# Fra:2 Mem:552.72M (Peak 591.21M) | Time:00:02.07 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.094
# Fra:2 Mem:553.33M (Peak 591.21M) | Time:00:02.07 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.103
# Fra:2 Mem:562.45M (Peak 602.28M) | Time:00:03.34 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Waiting for render to start
# Fra:2 Mem:562.45M (Peak 602.28M) | Time:00:03.34 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:2 Mem:562.45M (Peak 602.28M) | Time:00:03.79 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Scene
# Fra:2 Mem:562.45M (Peak 602.28M) | Time:00:03.79 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Shaders
# Fra:2 Mem:565.96M (Peak 602.28M) | Time:00:03.80 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Procedurals
# Fra:2 Mem:565.96M (Peak 602.28M) | Time:00:03.80 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Background
# Fra:2 Mem:565.96M (Peak 602.28M) | Time:00:03.80 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Camera
# Fra:2 Mem:565.96M (Peak 602.28M) | Time:00:03.80 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Meshes Flags
# Fra:2 Mem:565.96M (Peak 602.28M) | Time:00:03.80 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects
# Fra:2 Mem:565.96M (Peak 602.28M) | Time:00:03.80 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:2 Mem:565.98M (Peak 602.28M) | Time:00:03.80 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:2 Mem:565.98M (Peak 602.28M) | Time:00:03.80 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems
# Fra:2 Mem:565.98M (Peak 602.28M) | Time:00:03.80 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:2 Mem:565.98M (Peak 602.28M) | Time:00:03.80 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Meshes
# Fra:2 Mem:606.75M (Peak 606.75M) | Time:00:03.85 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:2 Mem:634.57M (Peak 634.57M) | Time:00:03.86 | Mem:51.85M, Peak:51.85M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:2 Mem:634.56M (Peak 634.57M) | Time:00:03.88 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Building BVH
# Fra:2 Mem:719.71M (Peak 719.71M) | Time:00:04.21 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Building BVH 74%, duplicates 0%
# Fra:2 Mem:719.71M (Peak 719.71M) | Time:00:04.24 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH triangles and strands
# Fra:2 Mem:725.39M (Peak 725.39M) | Time:00:04.24 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH nodes
# Fra:2 Mem:678.78M (Peak 746.91M) | Time:00:04.35 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:2 Mem:678.78M (Peak 746.91M) | Time:00:04.35 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:2 Mem:746.50M (Peak 746.91M) | Time:00:04.71 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH 59%, duplicates 0%
# Fra:2 Mem:746.50M (Peak 746.91M) | Time:00:04.84 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:2 Mem:751.02M (Peak 751.02M) | Time:00:04.84 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:2 Mem:839.94M (Peak 839.94M) | Time:00:05.01 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:2 Mem:839.94M (Peak 839.94M) | Time:00:05.43 | Mem:160.23M, Peak:160.23M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:2 Mem:953.07M (Peak 953.07M) | Time:00:05.50 | Mem:160.23M, Peak:160.23M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:2 Mem:953.07M (Peak 953.07M) | Time:00:05.58 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Objects Flags
# Fra:2 Mem:953.07M (Peak 953.07M) | Time:00:05.58 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:2 Mem:953.07M (Peak 953.07M) | Time:00:05.58 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Images
# Fra:2 Mem:953.07M (Peak 953.07M) | Time:00:05.58 | Mem:273.36M, Peak:273.36M | Scene, ViewLayer | Updating Images | Loading sky_nishita
# Fra:2 Mem:954.07M (Peak 954.07M) | Time:00:05.60 | Mem:274.36M, Peak:274.36M | Scene, ViewLayer | Updating Camera Volume
# Fra:2 Mem:954.07M (Peak 954.07M) | Time:00:05.60 | Mem:274.36M, Peak:274.36M | Scene, ViewLayer | Updating Lookup Tables
# Fra:2 Mem:954.07M (Peak 954.07M) | Time:00:05.60 | Mem:274.44M, Peak:274.44M | Scene, ViewLayer | Updating Lights
# Fra:2 Mem:954.07M (Peak 954.07M) | Time:00:05.60 | Mem:274.44M, Peak:274.44M | Scene, ViewLayer | Updating Lights | Importance map
# Fra:2 Mem:955.07M (Peak 959.57M) | Time:00:05.60 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:2 Mem:955.07M (Peak 959.57M) | Time:00:05.60 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Integrator
# Fra:2 Mem:955.07M (Peak 959.57M) | Time:00:05.61 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Film
# Fra:2 Mem:955.08M (Peak 959.57M) | Time:00:05.61 | Mem:275.37M, Peak:275.45M | Scene, ViewLayer | Updating Lookup Tables
# Fra:2 Mem:955.08M (Peak 959.57M) | Time:00:05.61 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Baking
# Fra:2 Mem:955.08M (Peak 959.57M) | Time:00:05.61 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:2 Mem:1062.52M (Peak 1062.52M) | Time:00:05.68 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Sample 0/1024
# Fra:2 Mem:1070.44M (Peak 1070.44M) | Time:00:05.82 | Remaining:02:27.83 | Mem:275.45M, Peak:275.45M | Scene, ViewLayer | Sample 1/1024
# Fra:2 Mem:1070.48M (Peak 1078.35M) | Time:00:06.29 | Remaining:00:05.91 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 96/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:06.53 | Remaining:00:06.96 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 112/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:07.76 | Remaining:00:14.52 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 128/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:07.98 | Remaining:00:14.06 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 144/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:08.22 | Remaining:00:13.69 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 160/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:08.45 | Remaining:00:13.35 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 176/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:08.71 | Remaining:00:13.12 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 192/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:09.95 | Remaining:00:16.74 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 208/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:10.16 | Remaining:00:15.98 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 224/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:10.38 | Remaining:00:15.34 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 240/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:10.60 | Remaining:00:14.75 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 256/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:10.88 | Remaining:00:14.38 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 272/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:12.11 | Remaining:00:16.43 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 288/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:12.32 | Remaining:00:15.73 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 304/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:12.54 | Remaining:00:15.08 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 320/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:12.78 | Remaining:00:14.53 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 336/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:13.06 | Remaining:00:14.08 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 352/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:14.29 | Remaining:00:15.34 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 368/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:14.54 | Remaining:00:14.75 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 384/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:14.76 | Remaining:00:14.17 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 400/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:14.98 | Remaining:00:13.58 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 416/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:15.23 | Remaining:00:13.08 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 432/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:16.44 | Remaining:00:13.83 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 448/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:16.65 | Remaining:00:13.23 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 464/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:16.85 | Remaining:00:12.66 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 480/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:17.07 | Remaining:00:12.12 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 496/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:17.40 | Remaining:00:11.71 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 512/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:18.60 | Remaining:00:12.13 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 528/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:18.81 | Remaining:00:11.58 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 544/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:19.02 | Remaining:00:11.05 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 560/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:19.24 | Remaining:00:10.54 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 576/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:19.57 | Remaining:00:10.13 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 592/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:20.79 | Remaining:00:10.33 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 608/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:20.99 | Remaining:00:09.81 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 624/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:21.22 | Remaining:00:09.32 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 640/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:21.43 | Remaining:00:08.83 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 656/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:21.74 | Remaining:00:08.41 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 672/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:22.96 | Remaining:00:08.43 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 688/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:23.18 | Remaining:00:07.95 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 704/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:23.39 | Remaining:00:07.47 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 720/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:23.60 | Remaining:00:07.01 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 736/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:23.92 | Remaining:00:06.59 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 752/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:24.78 | Remaining:00:06.36 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 768/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:25.14 | Remaining:00:05.95 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 784/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:25.36 | Remaining:00:05.51 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 800/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:25.58 | Remaining:00:05.07 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 816/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:25.81 | Remaining:00:04.64 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 832/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:26.09 | Remaining:00:04.23 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 848/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:27.10 | Remaining:00:03.96 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 864/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:27.32 | Remaining:00:03.54 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 880/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:27.54 | Remaining:00:03.12 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 896/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:27.75 | Remaining:00:02.71 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 912/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:27.97 | Remaining:00:02.30 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 928/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:28.27 | Remaining:00:01.91 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 944/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:29.15 | Remaining:00:01.56 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 960/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:29.50 | Remaining:00:01.17 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 976/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:29.71 | Remaining:00:00.77 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 992/1024
# Fra:2 Mem:1070.48M (Peak 1078.39M) | Time:00:29.92 | Remaining:00:00.38 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 1008/1024
# Fra:2 Mem:1073.99M (Peak 1081.03M) | Time:00:30.13 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Sample 1024/1024
# Fra:2 Mem:1073.99M (Peak 1081.03M) | Time:00:30.13 | Mem:275.45M, Peak:283.36M | Scene, ViewLayer | Finished
# Saved: '/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp/temp_img2.png'
# Time: 00:32.31 (Saving: 00:00.03)
#
# Fra:3 Mem:410.66M (Peak 410.66M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(4730346).spawn_asset(6552114)
# Fra:3 Mem:410.66M (Peak 410.66M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(4730346).spawn_asset(947399)
# Fra:3 Mem:410.66M (Peak 410.66M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SinkFactory(9203000).spawn_asset(807853)
# Fra:3 Mem:410.67M (Peak 410.67M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | LiteDoorFactory(5220690).spawn_asset(1)
# Fra:3 Mem:410.79M (Peak 410.79M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | PanelDoorFactory(1505269).spawn_asset(3)
# Fra:3 Mem:410.82M (Peak 410.82M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | GlassPanelDoorFactory(6323250).spawn_asset(4)
# Fra:3 Mem:410.82M (Peak 410.82M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(1)
# Fra:3 Mem:411.05M (Peak 411.10M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(2)
# Fra:3 Mem:411.21M (Peak 411.21M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(3)
# Fra:3 Mem:411.25M (Peak 411.25M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(4)
# Fra:3 Mem:411.28M (Peak 411.38M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(5)
# Fra:3 Mem:411.73M (Peak 411.73M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(6)
# Fra:3 Mem:411.90M (Peak 411.90M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(8)
# Fra:3 Mem:411.98M (Peak 411.98M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(9)
# Fra:3 Mem:412.07M (Peak 412.07M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(10)
# Fra:3 Mem:412.14M (Peak 412.14M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.wall
# Fra:3 Mem:413.11M (Peak 413.11M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.wall
# Fra:3 Mem:413.14M (Peak 413.14M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.floor
# Fra:3 Mem:414.24M (Peak 414.26M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.floor
# Fra:3 Mem:414.31M (Peak 414.31M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.floor
# Fra:3 Mem:414.30M (Peak 414.31M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.ceiling
# Fra:3 Mem:414.30M (Peak 414.31M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.ceiling
# Fra:3 Mem:414.68M (Peak 414.68M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.exterior
# Fra:3 Mem:415.13M (Peak 415.13M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.exterior
# Fra:3 Mem:415.16M (Peak 415.16M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.exterior
# Fra:3 Mem:415.25M (Peak 415.25M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.exterior
# Fra:3 Mem:415.38M (Peak 415.38M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SimpleBookcaseFactory(2630571).spawn_asset(6524038)
# Fra:3 Mem:415.38M (Peak 415.38M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SimpleBookcaseFactory(7865613).spawn_asset(6067366)
# Fra:3 Mem:415.77M (Peak 415.78M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | OvenFactory(2033892).spawn_asset(8574077)
# Fra:3 Mem:415.88M (Peak 415.88M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BeverageFridgeFactory(96617).spawn_asset(2208130)
# Fra:3 Mem:415.88M (Peak 415.88M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WallArtFactory(3906066).spawn_asset(5796891)
# Fra:3 Mem:416.47M (Peak 416.47M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WallArtFactory(1210002).spawn_asset(539140)
# Fra:3 Mem:416.46M (Peak 416.47M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2264099).spawn_asset(4874523)
# Fra:3 Mem:416.55M (Peak 416.55M) | Time:00:02.06 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2965383).spawn_asset(2745444)
# ...
# Fra:14 Mem:413.94M (Peak 413.94M) | Time:00:00.90 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | NatureShelfTrinketsFactory(2825353).spawn_asset(8069978)
# Fra:14 Mem:414.09M (Peak 414.09M) | Time:00:00.90 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2965383).spawn_asset(2745444)
# Fra:14 Mem:414.11M (Peak 414.12M) | Time:00:00.90 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(4324530).spawn_asset(3234797)
# Fra:14 Mem:449.75M (Peak 449.75M) | Time:00:00.90 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BookStackFactory(2491329).spawn_asset(8152350)
# Fra:14 Mem:452.41M (Peak 452.41M) | Time:00:00.90 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BookStackFactory(3677136).spawn_asset(891807)
# Fra:14 Mem:456.60M (Peak 456.61M) | Time:00:00.90 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(5055643).spawn_asset(4852438)
# Fra:14 Mem:456.71M (Peak 456.71M) | Time:00:00.90 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | skirtingboard_support
# Fra:14 Mem:552.40M (Peak 595.04M) | Time:00:01.02 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:14 Mem:552.13M (Peak 595.04M) | Time:00:01.02 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.104
# Fra:14 Mem:552.13M (Peak 595.04M) | Time:00:01.02 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.105
# Fra:14 Mem:552.13M (Peak 595.04M) | Time:00:01.02 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.040
# Fra:14 Mem:552.13M (Peak 595.04M) | Time:00:01.02 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.086
# Fra:14 Mem:552.13M (Peak 595.04M) | Time:00:01.02 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.103
# Fra:14 Mem:562.48M (Peak 602.30M) | Time:00:02.22 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Waiting for render to start
# Fra:14 Mem:562.48M (Peak 602.30M) | Time:00:02.22 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:14 Mem:562.48M (Peak 602.30M) | Time:00:02.70 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Scene
# Fra:14 Mem:562.48M (Peak 602.30M) | Time:00:02.70 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Shaders
# Fra:14 Mem:565.99M (Peak 602.30M) | Time:00:02.71 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Procedurals
# Fra:14 Mem:565.99M (Peak 602.30M) | Time:00:02.71 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Background
# Fra:14 Mem:565.99M (Peak 602.30M) | Time:00:02.71 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Camera
# Fra:14 Mem:565.99M (Peak 602.30M) | Time:00:02.71 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Meshes Flags
# Fra:14 Mem:565.99M (Peak 602.30M) | Time:00:02.71 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects
# Fra:14 Mem:565.99M (Peak 602.30M) | Time:00:02.71 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:14 Mem:566.01M (Peak 602.30M) | Time:00:02.71 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:14 Mem:566.01M (Peak 602.30M) | Time:00:02.71 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems
# Fra:14 Mem:566.01M (Peak 602.30M) | Time:00:02.71 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:14 Mem:566.01M (Peak 602.30M) | Time:00:02.71 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Meshes
# Fra:14 Mem:606.77M (Peak 606.77M) | Time:00:02.77 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:14 Mem:634.60M (Peak 634.60M) | Time:00:02.78 | Mem:51.85M, Peak:51.85M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:14 Mem:634.59M (Peak 634.60M) | Time:00:02.81 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Building BVH
# Fra:14 Mem:719.74M (Peak 719.74M) | Time:00:03.12 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH triangles and strands
# Fra:14 Mem:725.42M (Peak 725.42M) | Time:00:03.13 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH nodes
# Fra:14 Mem:678.81M (Peak 746.93M) | Time:00:03.25 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:14 Mem:678.81M (Peak 746.93M) | Time:00:03.25 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:14 Mem:746.53M (Peak 746.93M) | Time:00:03.59 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH 73%, duplicates 0%
# Fra:14 Mem:746.53M (Peak 746.93M) | Time:00:03.63 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:14 Mem:751.05M (Peak 751.05M) | Time:00:03.64 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:14 Mem:839.92M (Peak 839.92M) | Time:00:03.80 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:14 Mem:839.92M (Peak 839.92M) | Time:00:04.28 | Mem:160.21M, Peak:160.21M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:14 Mem:953.05M (Peak 953.05M) | Time:00:04.34 | Mem:160.21M, Peak:160.21M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:14 Mem:953.05M (Peak 953.05M) | Time:00:04.42 | Mem:273.34M, Peak:273.34M | Scene, ViewLayer | Updating Objects Flags
# Fra:14 Mem:953.05M (Peak 953.05M) | Time:00:04.42 | Mem:273.34M, Peak:273.34M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:14 Mem:953.05M (Peak 953.05M) | Time:00:04.42 | Mem:273.34M, Peak:273.34M | Scene, ViewLayer | Updating Images
# Fra:14 Mem:953.05M (Peak 953.05M) | Time:00:04.42 | Mem:273.34M, Peak:273.34M | Scene, ViewLayer | Updating Images | Loading sky_nishita
# Fra:14 Mem:954.05M (Peak 954.05M) | Time:00:04.43 | Mem:274.34M, Peak:274.34M | Scene, ViewLayer | Updating Camera Volume
# Fra:14 Mem:954.05M (Peak 954.05M) | Time:00:04.43 | Mem:274.34M, Peak:274.34M | Scene, ViewLayer | Updating Lookup Tables
# Fra:14 Mem:954.05M (Peak 954.05M) | Time:00:04.43 | Mem:274.42M, Peak:274.42M | Scene, ViewLayer | Updating Lights
# Fra:14 Mem:954.05M (Peak 954.05M) | Time:00:04.43 | Mem:274.42M, Peak:274.42M | Scene, ViewLayer | Updating Lights | Importance map
# Fra:14 Mem:955.06M (Peak 959.55M) | Time:00:04.44 | Mem:275.43M, Peak:275.43M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:14 Mem:955.06M (Peak 959.55M) | Time:00:04.44 | Mem:275.43M, Peak:275.43M | Scene, ViewLayer | Updating Integrator
# Fra:14 Mem:955.06M (Peak 959.55M) | Time:00:04.44 | Mem:275.43M, Peak:275.43M | Scene, ViewLayer | Updating Film
# Fra:14 Mem:955.06M (Peak 959.55M) | Time:00:04.44 | Mem:275.35M, Peak:275.43M | Scene, ViewLayer | Updating Lookup Tables
# Fra:14 Mem:955.06M (Peak 959.55M) | Time:00:04.44 | Mem:275.43M, Peak:275.43M | Scene, ViewLayer | Updating Baking
# Fra:14 Mem:955.06M (Peak 959.55M) | Time:00:04.44 | Mem:275.43M, Peak:275.43M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:14 Mem:1062.50M (Peak 1062.50M) | Time:00:04.51 | Mem:275.43M, Peak:275.43M | Scene, ViewLayer | Sample 0/1024
# Fra:14 Mem:1070.42M (Peak 1070.42M) | Time:00:04.65 | Remaining:02:24.78 | Mem:275.43M, Peak:275.43M | Scene, ViewLayer | Sample 1/1024
# Fra:14 Mem:1070.46M (Peak 1078.33M) | Time:00:05.10 | Remaining:00:05.76 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 96/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:05.39 | Remaining:00:07.18 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 112/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:06.62 | Remaining:00:14.78 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 128/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:06.84 | Remaining:00:14.23 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 144/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:07.07 | Remaining:00:13.81 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 160/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:07.30 | Remaining:00:13.44 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 176/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:07.56 | Remaining:00:13.23 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 192/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:08.79 | Remaining:00:16.80 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 208/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:09.03 | Remaining:00:16.14 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 224/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:09.26 | Remaining:00:15.53 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 240/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:09.50 | Remaining:00:14.98 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 256/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:10.16 | Remaining:00:15.62 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 272/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:10.96 | Remaining:00:16.47 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 288/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:11.17 | Remaining:00:15.77 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 304/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:11.39 | Remaining:00:15.13 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 320/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:11.60 | Remaining:00:14.52 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 336/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:11.90 | Remaining:00:14.11 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 352/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:13.13 | Remaining:00:15.36 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 368/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:13.36 | Remaining:00:14.74 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 384/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:13.58 | Remaining:00:14.15 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 400/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:13.80 | Remaining:00:13.58 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 416/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:14.07 | Remaining:00:13.10 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 432/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:15.16 | Remaining:00:13.69 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 448/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:15.40 | Remaining:00:13.14 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 464/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:15.62 | Remaining:00:12.59 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 480/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:15.86 | Remaining:00:12.08 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 496/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:16.09 | Remaining:00:11.57 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 512/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:16.56 | Remaining:00:11.32 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 528/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:17.49 | Remaining:00:11.45 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 544/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:17.72 | Remaining:00:10.94 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 560/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:17.94 | Remaining:00:10.44 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 576/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:18.17 | Remaining:00:09.96 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 592/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:18.44 | Remaining:00:09.53 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 608/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:19.45 | Remaining:00:09.57 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 624/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:19.68 | Remaining:00:09.10 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 640/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:19.88 | Remaining:00:08.62 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 656/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:20.09 | Remaining:00:08.16 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 672/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:20.31 | Remaining:00:07.71 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 688/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:20.61 | Remaining:00:07.32 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 704/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:21.63 | Remaining:00:07.22 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 720/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:21.84 | Remaining:00:06.78 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 736/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:22.05 | Remaining:00:06.34 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 752/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:22.26 | Remaining:00:05.91 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 768/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:22.47 | Remaining:00:05.49 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 784/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:22.79 | Remaining:00:05.11 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 800/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:23.80 | Remaining:00:04.91 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 816/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:24.01 | Remaining:00:04.50 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 832/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:24.23 | Remaining:00:04.09 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 848/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:24.44 | Remaining:00:03.69 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 864/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:24.65 | Remaining:00:03.29 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 880/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:25.11 | Remaining:00:02.94 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 896/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:26.17 | Remaining:00:02.66 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 912/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:26.38 | Remaining:00:02.26 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 928/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:26.57 | Remaining:00:01.86 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 944/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:26.77 | Remaining:00:01.48 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 960/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:26.98 | Remaining:00:01.10 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 976/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:27.58 | Remaining:00:00.74 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 992/1024
# Fra:14 Mem:1070.46M (Peak 1078.37M) | Time:00:28.02 | Remaining:00:00.37 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 1008/1024
# Fra:14 Mem:1073.98M (Peak 1081.01M) | Time:00:28.37 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Sample 1024/1024
# Fra:14 Mem:1073.98M (Peak 1081.01M) | Time:00:28.37 | Mem:275.43M, Peak:283.34M | Scene, ViewLayer | Finished
# Saved: '/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp/temp_img14.png'
# Time: 00:30.58 (Saving: 00:00.03)
#
# Collision at Frame 14

# %%
# continuously lower small object until intersecting large object
for i in range(50):
    small_obj.location.z -= 0.01
    small_tree = get_BVH_tree(small_obj)
    big_tree = get_BVH_tree(big_obj)
    inter = big_tree.overlap(small_tree)
    if inter:
        print(f"Collision at at index {i}")
        break

# %%
img_name = "temp_img"
render_and_log( os.path.join( "/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp", img_name ) )
# Out:
# Fra:4 Mem:410.67M (Peak 410.67M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(4730346).spawn_asset(6552114)
# Fra:4 Mem:410.67M (Peak 410.67M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | PanelDoorFactory(1505269).spawn_asset(2)
# Fra:4 Mem:410.67M (Peak 410.67M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | GlassPanelDoorFactory(6323250).spawn_asset(0)
# Fra:4 Mem:410.68M (Peak 410.69M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(0)
# Fra:4 Mem:410.75M (Peak 410.77M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(2)
# Fra:4 Mem:410.77M (Peak 410.77M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(3)
# Fra:4 Mem:410.81M (Peak 410.81M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(35558).spawn_asset(4)
# Fra:4 Mem:410.82M (Peak 410.82M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(5)
# Fra:4 Mem:410.88M (Peak 410.88M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(6)
# Fra:4 Mem:411.33M (Peak 411.34M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(7)
# Fra:4 Mem:411.92M (Peak 411.92M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(8)
# Fra:4 Mem:412.09M (Peak 412.09M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(6349).spawn_asset(10)
# Fra:4 Mem:412.11M (Peak 412.11M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.wall
# Fra:4 Mem:412.33M (Peak 412.33M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.wall
# Fra:4 Mem:412.72M (Peak 412.73M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.wall
# Fra:4 Mem:414.07M (Peak 414.07M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.floor
# Fra:4 Mem:414.20M (Peak 414.20M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.floor
# Fra:4 Mem:414.24M (Peak 414.25M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.floor
# Fra:4 Mem:414.54M (Peak 414.54M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.ceiling
# Fra:4 Mem:414.68M (Peak 414.68M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.ceiling
# Fra:4 Mem:414.87M (Peak 415.85M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.exterior
# Fra:4 Mem:416.22M (Peak 416.23M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bathroom_0/0.exterior
# Fra:4 Mem:416.80M (Peak 416.81M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.exterior
# Fra:4 Mem:416.94M (Peak 416.95M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SimpleBookcaseFactory(2630571).spawn_asset(6524038)
# Fra:4 Mem:417.20M (Peak 417.21M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | SimpleBookcaseFactory(7865613).spawn_asset(6067366)
# Fra:4 Mem:417.27M (Peak 417.27M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | LargePlantContainerFactory(3128120).spawn_asset(2241699)
# Fra:4 Mem:417.35M (Peak 417.35M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BeverageFridgeFactory(96617).spawn_asset(2208130)
# Fra:4 Mem:417.50M (Peak 417.50M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WallArtFactory(3906066).spawn_asset(5796891)
# Fra:4 Mem:417.64M (Peak 417.64M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WallArtFactory(1210002).spawn_asset(539140)
# Fra:4 Mem:417.90M (Peak 417.90M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2264099).spawn_asset(4874523)
# Fra:4 Mem:418.20M (Peak 418.22M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(2965383).spawn_asset(2745444)
# Fra:4 Mem:418.23M (Peak 418.23M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | NatureShelfTrinketsFactory(2825353).spawn_asset(8069978)
# Fra:4 Mem:418.30M (Peak 418.30M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | JarFactory(4380497).spawn_asset(6313724)
# Fra:4 Mem:418.40M (Peak 418.40M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | MicrowaveFactory(1849906).spawn_asset(842634)
# Fra:4 Mem:418.57M (Peak 418.57M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(4324530).spawn_asset(3234797)
# Fra:4 Mem:418.68M (Peak 418.68M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BookStackFactory(2491329).spawn_asset(8152350)
# Fra:4 Mem:420.00M (Peak 420.25M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | JarFactory(9132780).spawn_asset(5002085)
# Fra:4 Mem:420.67M (Peak 420.67M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBoxFactory(9833609).spawn_asset(5185903)
# Fra:4 Mem:422.12M (Peak 422.12M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CanFactory(5055643).spawn_asset(4852438)
# Fra:4 Mem:423.07M (Peak 423.07M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | FoodBagFactory(2438897).spawn_asset(3764059)
# Fra:4 Mem:424.32M (Peak 424.32M) | Time:00:00.92 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | skirtingboard_support
# Fra:4 Mem:552.38M (Peak 592.81M) | Time:00:01.05 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:4 Mem:552.11M (Peak 592.81M) | Time:00:01.05 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.105
# Fra:4 Mem:552.11M (Peak 592.81M) | Time:00:01.05 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.026
# Fra:4 Mem:552.11M (Peak 592.81M) | Time:00:01.05 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.033
# Fra:4 Mem:552.11M (Peak 592.81M) | Time:00:01.05 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.054
# Fra:4 Mem:552.11M (Peak 592.81M) | Time:00:01.05 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.088
# Fra:4 Mem:553.95M (Peak 592.81M) | Time:00:01.05 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.101
# Fra:4 Mem:554.56M (Peak 592.81M) | Time:00:01.05 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.099
# Fra:4 Mem:562.47M (Peak 602.30M) | Time:00:02.09 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Waiting for render to start
# Fra:4 Mem:562.48M (Peak 602.30M) | Time:00:02.09 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:4 Mem:562.48M (Peak 602.30M) | Time:00:02.52 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Scene
# Fra:4 Mem:562.48M (Peak 602.30M) | Time:00:02.52 | Mem:49.44M, Peak:49.44M | Scene, ViewLayer | Updating Shaders
# Fra:4 Mem:565.99M (Peak 602.30M) | Time:00:02.53 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Procedurals
# Fra:4 Mem:565.99M (Peak 602.30M) | Time:00:02.53 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Background
# Fra:4 Mem:565.99M (Peak 602.30M) | Time:00:02.53 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Camera
# Fra:4 Mem:565.99M (Peak 602.30M) | Time:00:02.53 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Meshes Flags
# Fra:4 Mem:565.99M (Peak 602.30M) | Time:00:02.53 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects
# Fra:4 Mem:565.99M (Peak 602.30M) | Time:00:02.53 | Mem:51.82M, Peak:51.82M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:4 Mem:566.00M (Peak 602.30M) | Time:00:02.53 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:4 Mem:566.00M (Peak 602.30M) | Time:00:02.54 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems
# Fra:4 Mem:566.00M (Peak 602.30M) | Time:00:02.54 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:4 Mem:566.00M (Peak 602.30M) | Time:00:02.54 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Meshes
# Fra:4 Mem:606.77M (Peak 606.77M) | Time:00:02.59 | Mem:51.84M, Peak:51.84M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:4 Mem:634.60M (Peak 634.60M) | Time:00:02.60 | Mem:51.85M, Peak:51.85M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:4 Mem:634.58M (Peak 634.60M) | Time:00:02.62 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Building BVH
# Fra:4 Mem:719.74M (Peak 719.74M) | Time:00:02.93 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH triangles and strands
# Fra:4 Mem:725.41M (Peak 725.41M) | Time:00:02.94 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Geometry BVH Circle.010 1/1 | Packing BVH nodes
# Fra:4 Mem:678.81M (Peak 746.93M) | Time:00:03.04 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:4 Mem:678.81M (Peak 746.93M) | Time:00:03.04 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:4 Mem:746.53M (Peak 746.93M) | Time:00:03.41 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Building BVH 93%, duplicates 0%
# Fra:4 Mem:746.53M (Peak 746.93M) | Time:00:03.43 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:4 Mem:751.04M (Peak 751.04M) | Time:00:03.43 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:4 Mem:840.02M (Peak 840.02M) | Time:00:03.61 | Mem:79.65M, Peak:79.65M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:4 Mem:840.02M (Peak 840.02M) | Time:00:04.16 | Mem:160.26M, Peak:160.26M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:4 Mem:953.14M (Peak 953.14M) | Time:00:04.22 | Mem:160.26M, Peak:160.26M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:4 Mem:953.14M (Peak 953.14M) | Time:00:04.31 | Mem:273.39M, Peak:273.39M | Scene, ViewLayer | Updating Objects Flags
# Fra:4 Mem:953.14M (Peak 953.14M) | Time:00:04.31 | Mem:273.39M, Peak:273.39M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:4 Mem:953.14M (Peak 953.14M) | Time:00:04.31 | Mem:273.39M, Peak:273.39M | Scene, ViewLayer | Updating Images
# Fra:4 Mem:953.14M (Peak 953.14M) | Time:00:04.31 | Mem:273.39M, Peak:273.39M | Scene, ViewLayer | Updating Images | Loading sky_nishita
# Fra:4 Mem:954.14M (Peak 954.14M) | Time:00:04.32 | Mem:274.39M, Peak:274.39M | Scene, ViewLayer | Updating Camera Volume
# Fra:4 Mem:954.14M (Peak 954.14M) | Time:00:04.32 | Mem:274.39M, Peak:274.39M | Scene, ViewLayer | Updating Lookup Tables
# Fra:4 Mem:954.14M (Peak 954.14M) | Time:00:04.32 | Mem:274.47M, Peak:274.47M | Scene, ViewLayer | Updating Lights
# Fra:4 Mem:954.15M (Peak 954.15M) | Time:00:04.32 | Mem:274.47M, Peak:274.47M | Scene, ViewLayer | Updating Lights | Importance map
# Fra:4 Mem:955.15M (Peak 959.65M) | Time:00:04.33 | Mem:275.47M, Peak:275.47M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:4 Mem:955.15M (Peak 959.65M) | Time:00:04.33 | Mem:275.48M, Peak:275.48M | Scene, ViewLayer | Updating Integrator
# Fra:4 Mem:955.15M (Peak 959.65M) | Time:00:04.33 | Mem:275.48M, Peak:275.48M | Scene, ViewLayer | Updating Film
# Fra:4 Mem:955.16M (Peak 959.65M) | Time:00:04.33 | Mem:275.39M, Peak:275.48M | Scene, ViewLayer | Updating Lookup Tables
# Fra:4 Mem:955.16M (Peak 959.65M) | Time:00:04.33 | Mem:275.48M, Peak:275.48M | Scene, ViewLayer | Updating Baking
# Fra:4 Mem:955.16M (Peak 959.65M) | Time:00:04.33 | Mem:275.48M, Peak:275.48M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:4 Mem:1062.60M (Peak 1062.60M) | Time:00:04.40 | Mem:275.48M, Peak:275.48M | Scene, ViewLayer | Sample 0/1024
# Fra:4 Mem:1070.51M (Peak 1070.51M) | Time:00:04.54 | Remaining:02:24.35 | Mem:275.48M, Peak:275.48M | Scene, ViewLayer | Sample 1/1024
# Fra:4 Mem:1070.55M (Peak 1078.42M) | Time:00:05.01 | Remaining:00:05.89 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 96/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:05.28 | Remaining:00:07.14 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 112/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:06.51 | Remaining:00:14.74 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 128/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:06.74 | Remaining:00:14.30 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 144/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:06.99 | Remaining:00:14.00 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 160/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:07.23 | Remaining:00:13.64 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 176/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:07.74 | Remaining:00:14.46 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 192/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:08.68 | Remaining:00:16.77 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 208/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:08.90 | Remaining:00:16.06 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 224/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:09.12 | Remaining:00:15.42 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 240/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:09.34 | Remaining:00:14.82 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 256/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:09.61 | Remaining:00:14.41 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 272/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:10.84 | Remaining:00:16.46 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 288/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:11.08 | Remaining:00:15.81 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 304/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:11.33 | Remaining:00:15.23 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 320/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:11.57 | Remaining:00:14.68 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 336/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:12.21 | Remaining:00:14.91 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 352/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:13.02 | Remaining:00:15.36 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 368/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:13.26 | Remaining:00:14.76 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 384/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:13.48 | Remaining:00:14.16 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 400/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:13.72 | Remaining:00:13.61 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 416/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:14.24 | Remaining:00:13.48 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 432/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:15.17 | Remaining:00:13.84 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 448/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:15.40 | Remaining:00:13.27 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 464/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:15.62 | Remaining:00:12.71 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 480/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:15.85 | Remaining:00:12.18 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 496/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:16.12 | Remaining:00:11.72 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 512/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:17.34 | Remaining:00:12.15 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 528/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:17.55 | Remaining:00:11.60 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 544/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:17.77 | Remaining:00:11.07 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 560/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:18.00 | Remaining:00:10.57 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 576/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:18.29 | Remaining:00:10.13 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 592/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:19.51 | Remaining:00:10.34 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 608/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:19.74 | Remaining:00:09.83 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 624/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:19.95 | Remaining:00:09.33 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 640/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:20.17 | Remaining:00:08.84 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 656/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:20.47 | Remaining:00:08.41 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 672/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:21.49 | Remaining:00:08.34 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 688/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:21.72 | Remaining:00:07.87 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 704/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:21.95 | Remaining:00:07.40 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 720/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:22.17 | Remaining:00:06.95 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 736/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:22.41 | Remaining:00:06.51 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 752/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:22.66 | Remaining:00:06.08 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 768/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:23.52 | Remaining:00:05.85 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 784/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:23.74 | Remaining:00:05.41 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 800/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:23.97 | Remaining:00:04.98 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 816/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:24.19 | Remaining:00:04.56 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 832/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:24.42 | Remaining:00:04.15 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 848/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:24.64 | Remaining:00:03.74 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 864/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:25.15 | Remaining:00:03.39 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 880/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:25.72 | Remaining:00:03.04 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 896/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:26.08 | Remaining:00:02.66 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 912/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:26.30 | Remaining:00:02.26 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 928/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:26.53 | Remaining:00:01.87 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 944/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:26.75 | Remaining:00:01.49 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 960/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:27.03 | Remaining:00:01.11 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 976/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:28.04 | Remaining:00:00.76 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 992/1024
# Fra:4 Mem:1070.55M (Peak 1078.46M) | Time:00:28.26 | Remaining:00:00.37 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 1008/1024
# Fra:4 Mem:1074.07M (Peak 1081.10M) | Time:00:28.49 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Sample 1024/1024
# Fra:4 Mem:1074.07M (Peak 1081.10M) | Time:00:28.49 | Mem:275.48M, Peak:283.39M | Scene, ViewLayer | Finished
# Saved: '/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp/temp_img.png'
# Time: 00:30.65 (Saving: 00:00.03)

# %% [markdown]
# # Mini Solver Test

# %%
def max_min_bound_box( obj, local = False ):
    for idx, corner in enumerate(obj.bound_box):
        if local:
            vec_corner = Vector(corner) # coordinates relative to object origin (obj.location)
        else:
            vec_corner = obj.matrix_world @ Vector(corner)
        if idx == 0:
            max_min_dict = {
                "x_max": vec_corner.x,
                "x_min": vec_corner.x,
                "y_max": vec_corner.y,
                "y_min": vec_corner.y,
                "z_max": vec_corner.z,
                "z_min": vec_corner.z
            }
        else:
            max_min_dict["x_max"] = max( max_min_dict["x_max"], vec_corner.x )
            max_min_dict["x_min"] = min( max_min_dict["x_min"], vec_corner.x )
            max_min_dict["y_max"] = max( max_min_dict["y_max"], vec_corner.y )
            max_min_dict["y_min"] = min( max_min_dict["y_min"], vec_corner.y )
            max_min_dict["z_max"] = max( max_min_dict["z_max"], vec_corner.z )
            max_min_dict["z_min"] = min( max_min_dict["z_min"], vec_corner.z )
    return max_min_dict

# %%
def put_small_obj_over_big_obj( small_obj, big_obj ):
    """Uses bounding boxes to roughly move the small_obj on the big_obj"""
    small_obj_mmD = max_min_bound_box(small_obj)
    big_obj_mmD = max_min_bound_box( big_obj )
    
    # align center of small_obj with big_obj for the x,y dimensions
    # get center of small_obj x,y
    small_obj_cx = (small_obj_mmD["x_min"] + small_obj_mmD["x_max"]) / 2
    small_obj_cy = (small_obj_mmD["y_min"] + small_obj_mmD["y_max"]) / 2

    # get center of big_obj x,y
    big_obj_cx = (big_obj_mmD["x_min"] + big_obj_mmD["x_max"]) / 2
    big_obj_cy = (big_obj_mmD["y_min"] + big_obj_mmD["y_max"]) / 2

    # calculate displacement
    disp_x = big_obj_cx - small_obj_cx
    disp_y = big_obj_cy - small_obj_cy


    # get bottom of small_obj to line up with top of big_obj
    disp_z = big_obj_mmD["z_max"] - small_obj_mmD["z_min"]

    # # move small object origin
    # small_obj.location += Vector((disp_x, disp_y, disp_z))

    # copy & modify the world matrix
    mw = small_obj.matrix_world.copy()
    mw.translation += Vector((disp_x, disp_y, disp_z))

    # # Might need this if object "jumps"
    # small_obj.matrix_parent_inverse = small_obj.parent.matrix_world.inverted()

    # assign it back
    small_obj.matrix_world = mw

    bpy.context.view_layer.update()  # Ensure updates are processed

# %%
# Version 1. some helper methods are still used in V2

def solve_xy_on_flat_surface( small_obj, big_obj, dataset_path, scene_id, partitions=8 ):
    """Given small object's z coordinate is correct, move it along flat surface
    Returns 2D info matrixs where each element is tuple
    ( corners_in_clip, is_center_visible_by_raycast, count_ray_hits_to_camera, intersects_objects ) """

    # have the middle of the small_obj align with the top left corner of big_obj
    small_obj_mmD = max_min_bound_box(small_obj)
    big_obj_mmD = max_min_bound_box( big_obj )
    small_obj_cx = (small_obj_mmD["x_min"] + small_obj_mmD["x_max"]) / 2 # small object center
    small_obj_cy = (small_obj_mmD["y_min"] + small_obj_mmD["y_max"]) / 2
    big_obj_tlx, big_obj_tly = big_obj_mmD["x_min"], big_obj_mmD["y_max"] # top left corner large object
    origin_to_center = Vector(( small_obj_cx - small_obj.matrix_world.translation.x, 
                              small_obj_cy - small_obj.matrix_world.translation.y, 0 ))
    center_to_top_left_corner = Vector(( big_obj_tlx - small_obj_cx, big_obj_tly - small_obj_cy, 0 ))
    
    # Compute your “base” matrix once
    base_mw = small_obj.matrix_world.copy()
    base_mw.translation += origin_to_center + center_to_top_left_corner
    # Move object to the top–left only once
    small_obj.matrix_world = base_mw
    bpy.context.view_layer.update()

    width  = big_obj_mmD["x_max"] - big_obj_mmD["x_min"]
    height = big_obj_mmD["y_max"] - big_obj_mmD["y_min"]
    dx = width  / partitions
    dy = height / partitions

    # preallocate your score matrix
    info_matrix = [[None]*partitions for _ in range(partitions)]

    for i in range(partitions):
        for j in range(partitions):
            mw = base_mw.copy()
            mw.translation += Vector((i*dx, -j*dy, 0))
            small_obj.matrix_world = mw
            bpy.context.view_layer.update()

            # update info matrix:
            scene = bpy.context.scene
            cam = scene.camera
            info_matrix[j][i] = (corners_in_clip(scene, cam, small_obj), 
                                 is_center_visible_by_raycast(scene, cam, small_obj),
                                 count_ray_hits_to_camera(scene, cam, small_obj),
                                intersects_objects(small_obj, big_obj, dataset_path, scene_id) )
            
            # just for testing we render as well
            # img_name = f"temp_img(j={j}, i={i} )"
            # render_and_log( os.path.join( "/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp", img_name ) )

    return info_matrix
    

def corners_in_clip(scene, cam_obj, obj):
    cam_data = cam_obj.data
    mat = obj.matrix_world
    
    # count how many corners are in the clip
    count = 0

    for corner in obj.bound_box:
        co_world = mat @ Vector(corner)
        ndc = world_to_camera_view(scene, cam_obj, co_world)
        # ndc.x/y in [0,1] is in‐frame; ndc.z is the depth on the view axis
        if (0.0 <= ndc.x <= 1.0 and
            0.0 <= ndc.y <= 1.0 and
            cam_data.clip_start < ndc.z < cam_data.clip_end):
            count += 1
    return count


def is_center_visible_by_raycast(scene, cam_obj, target_obj):
    """See if raycast from camera can hit center of object's bound box"""
    cam_loc = cam_obj.matrix_world.to_translation()
    # test against object’s bounding‐box center
    bbox_center = sum((Vector(c) for c in target_obj.bound_box), Vector()) / 8.0
    wc_center = target_obj.matrix_world @ bbox_center
    direction = (wc_center - cam_loc).normalized()

    result, hit_loc, hit_norm, _, hit_obj, _ = scene.ray_cast(
        depsgraph=bpy.context.evaluated_depsgraph_get(),
        origin=cam_loc,
        direction=direction
    )
    return result and hit_obj == target_obj

def count_ray_hits_to_camera(scene, cam_obj, target_obj, epsilon=1e-4):
    """
    Cast rays from the target_obj’s 8 bounding‑box corners
    toward the camera. Return how many of those 8 rays reach the 
    camera without hitting any meshes
    """
    depsgraph = bpy.context.evaluated_depsgraph_get()
    cam_loc   = cam_obj.matrix_world.to_translation()

    # build the 9 sample points in local space
    local_corners = [Vector(c) for c in target_obj.bound_box]

    hit_count = 0
    for lp in local_corners:
        # world‑space origin of the ray
        origin    = target_obj.matrix_world @ lp
        direction = (cam_loc - origin).normalized()

        # offset a bit so we don’t immediately self‑hit
        origin_offset = origin + direction * epsilon
        max_dist      = (cam_loc - origin_offset).length

        hit, hit_loc, hit_norm, face_idx, hit_obj, matrix = scene.ray_cast(
            depsgraph,
            origin=origin_offset,
            direction=direction,
            distance=max_dist
        )
        
        # If no mesh is hit then the ray hit the camera safely
        if not hit:
            hit_count += 1

    return hit_count

def intersects_objects(small_obj, big_obj, dataset_path, scene_id):
    """determine if small_obj intersects any dependents of the big_obj (except the small object itself)"""
    mDct = getMasterDict( dataset_path, scene_id )
    small_obj_name = small_obj.name
    big_obj_name = big_obj.name

    for dependent in mDct["dependents_map"][big_obj_name]:
        if dependent == small_obj_name: # don't want to check if intersects with self
            continue
        if aabb_intersect( small_obj, bpy.data.objects[dependent] ):
            return True
    return False

def aabb_intersect(obj_a, obj_b, check_z=True):
    mmA = max_min_bound_box(obj_a)
    mmB = max_min_bound_box(obj_b)
    overlap_x = mmA["x_max"] >= mmB["x_min"] and mmB["x_max"] >= mmA["x_min"]
    overlap_y = mmA["y_max"] >= mmB["y_min"] and mmB["y_max"] >= mmA["y_min"]
    if not (overlap_x and overlap_y):
        return False
    if check_z:
        overlap_z = mmA["z_max"] >= mmB["z_min"] and mmB["z_max"] >= mmA["z_min"]
        return overlap_z
    return True

# %%
# version 2
# ***over writes "solve_xy_on_flat_surface" from above
# "solve_xy_on_flat_surface" still uses the helper functions from above though

def raycast_top_grid( obj, x_min, x_max, y_min, y_max, z_origin, partitions=100 ):
    """ castsrays from a grid defined by x_min, x_max, y_min, y_max, z_origin, partitions
     reutrns an array of all vertices of obj that were hit """
    hits = []
    depsgraph = bpy.context.evaluated_depsgraph_get()
    scene = bpy.context.scene
    direction = Vector((0,0,-1))
    
    for i in range(partitions):
        for j in range(partitions):
            x_origin = x_min + (x_max - x_min) * (i/(partitions-1))
            y_origin = y_min + (y_max - y_min) * (j/(partitions-1))
            origin = Vector( (x_origin, y_origin, z_origin) )

            result, hit_loc, hit_norm, hit_idx, hit_obj, hit_mat = scene.ray_cast(
                depsgraph, origin + direction*1e-3, direction
            )
            if result:
                hits.append( Vector((x_origin, y_origin, hit_loc.z)) )
    return hits


def find_top_plane( hits ):
    """ takes the hits array from raycast_top_grid and returns a flat plane using
    the median z-coordinates, and min and max x,y coordinates that are within eps
    away from the median z-coordinate"""

    # if somehow all the rays missed and hits is empty
    if not hits:
        raise ValueError("No ray hits—can't compute top plane.")

    hits_x = sorted(hits, key=lambda vec: vec.x)
    hits_y = sorted(hits, key=lambda vec: vec.y)
    hits_z = sorted(hits, key=lambda vec: vec.z)
    z_median = hits_z[ len(hits)//2 ].z

    # filter out points that are more than epsilon away from z-median
    eps = 1e-3
    hits_x = [ point for point in hits_x if abs(point.z - z_median) < eps ]
    hits_y = [ point for point in hits_y if abs(point.z - z_median) < eps ]

    x_min = hits_x[0].x
    x_max = hits_x[len(hits_x)-1].x
    y_min = hits_y[0].y
    y_max = hits_y[len(hits_y)-1].y

    return ( x_min, x_max, y_min, y_max, z_median )


def solve_xy_on_flat_surface( small_obj, big_obj, top_plane, dataset_path, scene_id, partitions=10 ):
    """Given a top_plane, align small_obj's bottom z to top_plane's z. Then slide small_obj's xy coordinates
    along the plane.
    Returns 2D info matrixs where each element is tuple
    ( corners_in_clip, is_center_visible_by_raycast, count_ray_hits_to_camera, intersects_objects ) 
    
    [0, partitions] is the interval used to slide objects around in the x and y axis
    
    top_plane should be in the form ( x_min, x_max, y_min, y_max, z_median )
    which is what find_top_plane returns
    """

    tp_x_min, tp_x_max, tp_y_min, tp_y_max, tp_z_median = top_plane

    # have the middle of the small_obj align with the top left corner of top_plane
    small_obj_mmD = max_min_bound_box(small_obj)
    small_obj_cx = (small_obj_mmD["x_min"] + small_obj_mmD["x_max"]) / 2 # small object center
    small_obj_cy = (small_obj_mmD["y_min"] + small_obj_mmD["y_max"]) / 2
    center_to_top_left_corner = Vector(( tp_x_min - small_obj_cx, tp_y_max - small_obj_cy, 0 ))

    # also need a transform to align bottom of small_obj to the top_plane
    vec_z = Vector( (0,0, tp_z_median - small_obj_mmD["z_min"] ) )
    
    # Compute your “base” matrix once
    base_mw = small_obj.matrix_world.copy()
    base_mw.translation += center_to_top_left_corner + vec_z
    # Move object to the top–left only once
    small_obj.matrix_world = base_mw
    bpy.context.view_layer.update()

    width  = tp_x_max - tp_x_min
    height = tp_y_max - tp_y_min
    dx = width  / partitions
    dy = height / partitions

    # preallocate your score matrix
    info_matrix = [[None]*(partitions+1) for _ in range(partitions+1)]

    for i in range(partitions + 1):
        for j in range(partitions + 1):
            mw = base_mw.copy()
            mw.translation += Vector((i*dx, -j*dy, 0))
            small_obj.matrix_world = mw
            bpy.context.view_layer.update()

            # update info matrix:
            scene = bpy.context.scene
            cam = scene.camera
            info_matrix[j][i] = (corners_in_clip(scene, cam, small_obj), 
                                 is_center_visible_by_raycast(scene, cam, small_obj),
                                 count_ray_hits_to_camera(scene, cam, small_obj),
                                intersects_objects(small_obj, big_obj, dataset_path, scene_id),
                                 mw )
            
            # just for testing we render as well
            # img_name = f"temp_img(j={j}, i={i} )"
            # render_and_log( os.path.join( "/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp", img_name ) )

    return info_matrix


def align_small_object_with_parenting( parent, child ):
    """ Used to have child's axis line up with parent's axis
     Front is +X in infinigen """
    child.parent = parent

    # zero out child transforms
    child.matrix_basis.identity()
    
    # — Default: “no inverse” → child inherits parent’s transform immediately
    child.matrix_parent_inverse.identity()

    bpy.context.view_layer.update()

# %%
# specific add on for kitchenSpace
def largest_z_gap(obj):
    # 1) Collect all the Z‐coordinates
    zs = []
    
    # transform every 50 local vertex into world space:
    for i in range( 0, len(obj.data.vertices), 50 ):
        v = obj.data.vertices[i]
        co_world = obj.matrix_world @ v.co
        zs.append(co_world.z)

    # 2) Sort them
    zs_sorted = sorted(zs)

    # 3) Walk the sorted list and track the maximum gap
    max_gap = 0.0
    max_pair = (None, None)
    for a, b in zip(zs_sorted, zs_sorted[1:]):
        gap = b - a
        if gap > max_gap:
            max_gap = gap
            max_pair = (a, b)

    return max_gap, max_pair

# use something like (max_pair[0] + max_pair[1])/2 to float above the bottom counter

# %%
# add on to place object in best location

# info_matrix[j][i] = (corners_in_clip(scene, cam, small_obj), 
#                      is_center_visible_by_raycast(scene, cam, small_obj),
#                      count_ray_hits_to_camera(scene, cam, small_obj),
#                     intersects_objects(small_obj, big_obj, dataset_path, scene_id),
#                      mw )

def put_object_in_best_loc( obj, info_matrix ):
    """ Given an info matrix for an obj, move the obj to the 'best' location """
    score_list = [] # element = ( i, j, score )

    n = len( info_matrix )
    for i in range( n ):
        for j in range( n ):
            score = 0
            info = info_matrix[j][i] # info matrix is index x,y or j,i

            # if nothing is in clip, instant -1000
            if info[0] == 0:
                score_list.append( (i,j, -1000) )
                continue
            else:
                # get 200 pts for every vertex in clip
                score += 200 * info[0]
            
            # if center is visible +500
            if info[1]:
                score += 500
            
            # if intersecting other objects -750
            if info[3]:
                score -= 750
            
            # extra 100 for each corner visible
            score += info[2] * 100

            # edge case: center and all corners not visible, instant -1000
            if not info[1] and info[2]==0:
                score_list.append( (i,j, -1000) )
                continue

            # penalty for being on the outer edge -100
            if i==0 or i==n-1 or j==0 or j==n-1:
                score -= 100
            
            # additional scaling penalty for being away from center up to -500
            units_from_center = abs(i + j - n)
            score -= (units_from_center / n) * 500

            # add to score list
            score_list.append( (i, j, score) )
    
    # get the tuple corresponding to the max score and move object there
    best_tuple = max(score_list, key=lambda x: x[2])
    best_i, best_j, best_score = best_tuple
    mw = info_matrix[best_j][best_i][4]
    obj.matrix_world = mw
    bpy.context.view_layer.update()

    # returns scorelist and best_tuple for analysis purposes
    return score_list, best_tuple

# %% [markdown]
# v1: hope that putting the object on top lines everything up

# %%
dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/diningRoom99"
scene_id = "1cc42ce1"

# open blender scene
blender_scene_path = os.path.join( dataset_path, scene_id, "fine", "scene.blend" )
bpy.ops.wm.open_mainfile(filepath = blender_scene_path)
print(flush=True)
config_GPU_and_render_quality()

# GOAL: Move wine glass to table
wineglass_name = "WineglassFactory(1028783).spawn_asset(2729829)"
table_name = "TableDiningFactory(5721013).spawn_asset(481368)"
wineglass = bpy.data.objects[wineglass_name]
table = bpy.data.objects[table_name]
# Out:
# Read blend: "/n/fs/obj-cv/infinigen_project/savedDatasets/diningRoom99/1cc42ce1/fine/scene.blend"
#
# Scene name: Scene
# Engine      : CYCLES
# Backend     : CUDA
# Scene device: GPU
# Available devices:
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - Intel Xeon Gold 5320 CPU @ 2.20GHz type=CPU  use=False
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True

# %%
# Render to temp
img_name = "temp_img"
render_and_log( os.path.join( "/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp", img_name ) )
# Out:
# Fra:1 Mem:252.11M (Peak 252.11M) | Time:00:00.87 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | CeilingLightFactory(8723727).spawn_asset(2390609)
# Fra:1 Mem:252.12M (Peak 252.12M) | Time:00:00.87 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | LiteDoorFactory(178947).spawn_asset(1)
# Fra:1 Mem:252.12M (Peak 252.12M) | Time:00:00.87 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(0)
# Fra:1 Mem:252.13M (Peak 252.13M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(2)
# Fra:1 Mem:252.16M (Peak 252.16M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(4)
# Fra:1 Mem:252.20M (Peak 252.20M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(5)
# Fra:1 Mem:252.21M (Peak 252.21M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(7)
# Fra:1 Mem:252.34M (Peak 252.34M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(8)
# Fra:1 Mem:252.41M (Peak 252.41M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(10)
# Fra:1 Mem:252.53M (Peak 252.55M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(11)
# Fra:1 Mem:252.60M (Peak 252.60M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(12)
# Fra:1 Mem:252.68M (Peak 252.68M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(13)
# Fra:1 Mem:253.40M (Peak 253.44M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(14)
# Fra:1 Mem:253.62M (Peak 253.62M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(15)
# Fra:1 Mem:253.80M (Peak 253.82M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(40396).spawn_asset(16)
# Fra:1 Mem:253.99M (Peak 253.99M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(40396).spawn_asset(17)
# Fra:1 Mem:254.07M (Peak 254.07M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(18)
# Fra:1 Mem:254.13M (Peak 254.13M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(19)
# Fra:1 Mem:254.38M (Peak 254.38M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | WindowFactory(4459).spawn_asset(20)
# Fra:1 Mem:254.98M (Peak 255.27M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.wall
# Fra:1 Mem:255.48M (Peak 255.48M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | dining-room_0/0.wall
# Fra:1 Mem:255.55M (Peak 255.55M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | living-room_0/0.floor
# Fra:1 Mem:256.81M (Peak 256.81M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.floor
# Fra:1 Mem:256.92M (Peak 256.92M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.floor
# Fra:1 Mem:256.99M (Peak 256.99M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.ceiling
# Fra:1 Mem:257.07M (Peak 257.09M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.ceiling
# Fra:1 Mem:257.20M (Peak 257.27M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | bedroom_0/0.exterior
# Fra:1 Mem:257.50M (Peak 257.50M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | kitchen_0/0.exterior
# Fra:1 Mem:257.78M (Peak 257.78M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | LargeShelfFactory(2741555).spawn_asset(1952064)
# Fra:1 Mem:257.81M (Peak 257.81M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | BottleFactory(1493237).spawn_asset(8652564)
# Fra:1 Mem:258.85M (Peak 259.04M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | NatureShelfTrinketsFactory(1193877).spawn_asset(7322408)
# Fra:1 Mem:259.63M (Peak 259.75M) | Time:00:00.88 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | skirtingboard_support
# Fra:1 Mem:341.01M (Peak 348.86M) | Time:00:00.98 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:340.79M (Peak 348.86M) | Time:00:00.98 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.007
# Fra:1 Mem:340.79M (Peak 348.86M) | Time:00:00.98 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.008
# Fra:1 Mem:340.79M (Peak 348.86M) | Time:00:00.98 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Updating Images | Loading text_texture.006
# Fra:1 Mem:333.36M (Peak 348.86M) | Time:00:01.00 | Mem:3.05M, Peak:3.05M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:333.36M (Peak 348.86M) | Time:00:01.00 | Mem:3.05M, Peak:3.05M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:333.36M (Peak 362.01M) | Time:00:01.45 | Mem:3.05M, Peak:3.05M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:333.36M (Peak 362.01M) | Time:00:01.45 | Mem:3.05M, Peak:3.05M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:333.93M (Peak 362.01M) | Time:00:01.45 | Mem:3.47M, Peak:3.47M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:333.93M (Peak 362.01M) | Time:00:01.45 | Mem:3.47M, Peak:3.47M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:333.93M (Peak 362.01M) | Time:00:01.45 | Mem:3.47M, Peak:3.47M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:333.93M (Peak 362.01M) | Time:00:01.45 | Mem:3.47M, Peak:3.47M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:333.93M (Peak 362.01M) | Time:00:01.45 | Mem:3.47M, Peak:3.47M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:333.93M (Peak 362.01M) | Time:00:01.45 | Mem:3.47M, Peak:3.47M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:333.95M (Peak 362.01M) | Time:00:01.45 | Mem:3.48M, Peak:3.48M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:333.95M (Peak 362.01M) | Time:00:01.45 | Mem:3.48M, Peak:3.48M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:333.95M (Peak 362.01M) | Time:00:01.45 | Mem:3.48M, Peak:3.48M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:333.95M (Peak 362.01M) | Time:00:01.45 | Mem:3.48M, Peak:3.48M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:350.04M (Peak 362.01M) | Time:00:01.48 | Mem:3.48M, Peak:3.48M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:364.23M (Peak 364.23M) | Time:00:01.49 | Mem:3.49M, Peak:3.49M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:364.22M (Peak 364.23M) | Time:00:01.50 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Geometry BVH Circle.012 1/2 | Building BVH
# Fra:1 Mem:364.22M (Peak 364.23M) | Time:00:01.50 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Geometry BVH Circle.014 2/2 | Building BVH
# Fra:1 Mem:364.26M (Peak 364.26M) | Time:00:01.50 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Geometry BVH Circle.014 2/2 | Packing BVH triangles and strands
# Fra:1 Mem:364.26M (Peak 364.26M) | Time:00:01.50 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Geometry BVH Circle.014 2/2 | Packing BVH nodes
# Fra:1 Mem:364.25M (Peak 364.26M) | Time:00:01.50 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Geometry BVH Circle.014 2/2 | Packing BVH triangles and strands
# Fra:1 Mem:364.25M (Peak 364.26M) | Time:00:01.50 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Geometry BVH Circle.014 2/2 | Packing BVH nodes
# Fra:1 Mem:364.24M (Peak 364.26M) | Time:00:01.50 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:364.24M (Peak 364.26M) | Time:00:01.50 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:424.53M (Peak 424.53M) | Time:00:01.81 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Scene BVH | Building BVH 52%, duplicates 0%
# Fra:1 Mem:424.53M (Peak 424.53M) | Time:00:01.86 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:1 Mem:428.55M (Peak 428.55M) | Time:00:01.87 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Scene BVH | Packing BVH nodes
# Fra:1 Mem:427.76M (Peak 444.23M) | Time:00:01.95 | Mem:17.67M, Peak:17.67M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:427.76M (Peak 444.23M) | Time:00:01.99 | Mem:49.43M, Peak:49.43M | Scene, ViewLayer | Updating Mesh | Computing normals
# Fra:1 Mem:471.17M (Peak 471.17M) | Time:00:02.00 | Mem:49.43M, Peak:49.43M | Scene, ViewLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:471.17M (Peak 471.17M) | Time:00:02.04 | Mem:92.84M, Peak:92.84M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:471.17M (Peak 471.17M) | Time:00:02.04 | Mem:92.84M, Peak:92.84M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:471.17M (Peak 471.17M) | Time:00:02.04 | Mem:92.84M, Peak:92.84M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:471.17M (Peak 471.17M) | Time:00:02.04 | Mem:92.84M, Peak:92.84M | Scene, ViewLayer | Updating Images | Loading sky_nishita
# Fra:1 Mem:472.17M (Peak 472.17M) | Time:00:02.05 | Mem:93.84M, Peak:93.84M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:472.17M (Peak 472.17M) | Time:00:02.05 | Mem:93.84M, Peak:93.84M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:472.17M (Peak 472.17M) | Time:00:02.05 | Mem:93.92M, Peak:93.92M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:472.18M (Peak 472.18M) | Time:00:02.05 | Mem:93.92M, Peak:93.92M | Scene, ViewLayer | Updating Lights | Importance map
# Fra:1 Mem:473.18M (Peak 477.68M) | Time:00:02.06 | Mem:94.93M, Peak:94.93M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:473.18M (Peak 477.68M) | Time:00:02.06 | Mem:94.93M, Peak:94.93M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:473.18M (Peak 477.68M) | Time:00:02.06 | Mem:94.93M, Peak:94.93M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:473.19M (Peak 477.68M) | Time:00:02.06 | Mem:94.85M, Peak:94.93M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:473.19M (Peak 477.68M) | Time:00:02.06 | Mem:94.93M, Peak:94.93M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:473.19M (Peak 477.68M) | Time:00:02.06 | Mem:94.93M, Peak:94.93M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:579.93M (Peak 579.93M) | Time:00:02.13 | Mem:94.93M, Peak:94.93M | Scene, ViewLayer | Sample 0/1024
# Fra:1 Mem:587.85M (Peak 587.85M) | Time:00:02.16 | Remaining:00:35.28 | Mem:94.93M, Peak:94.93M | Scene, ViewLayer | Sample 1/1024
# Fra:1 Mem:587.89M (Peak 595.76M) | Time:00:02.32 | Remaining:00:01.86 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 96/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.38 | Remaining:00:02.08 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 112/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.44 | Remaining:00:02.21 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 128/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.51 | Remaining:00:02.31 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 144/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.57 | Remaining:00:02.38 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 160/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.63 | Remaining:00:02.42 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 176/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.69 | Remaining:00:02.45 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 192/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.76 | Remaining:00:02.46 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 208/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.82 | Remaining:00:02.46 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 224/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.88 | Remaining:00:02.45 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 240/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:02.94 | Remaining:00:02.44 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 256/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.00 | Remaining:00:02.41 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 272/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.06 | Remaining:00:02.39 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 288/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.13 | Remaining:00:02.36 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 304/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.19 | Remaining:00:02.32 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 320/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.25 | Remaining:00:02.28 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 336/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.31 | Remaining:00:02.25 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 352/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.37 | Remaining:00:02.21 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 368/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.43 | Remaining:00:02.16 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 384/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.49 | Remaining:00:02.12 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 400/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.55 | Remaining:00:02.07 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 416/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.60 | Remaining:00:02.02 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 432/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.66 | Remaining:00:01.97 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 448/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.72 | Remaining:00:01.92 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 464/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.78 | Remaining:00:01.87 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 480/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.84 | Remaining:00:01.82 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 496/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.90 | Remaining:00:01.77 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 512/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:03.96 | Remaining:00:01.72 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 528/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.02 | Remaining:00:01.66 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 544/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.08 | Remaining:00:01.61 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 560/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.13 | Remaining:00:01.56 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 576/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.20 | Remaining:00:01.50 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 592/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.26 | Remaining:00:01.45 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 608/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.32 | Remaining:00:01.40 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 624/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.37 | Remaining:00:01.34 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 640/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.43 | Remaining:00:01.29 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 656/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.49 | Remaining:00:01.23 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 672/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.55 | Remaining:00:01.18 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 688/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.61 | Remaining:00:01.12 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 704/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.67 | Remaining:00:01.07 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 720/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.72 | Remaining:00:01.01 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 736/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.78 | Remaining:00:00.95 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 752/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.84 | Remaining:00:00.90 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 768/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.90 | Remaining:00:00.84 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 784/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:04.96 | Remaining:00:00.79 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 800/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.02 | Remaining:00:00.73 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 816/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.08 | Remaining:00:00.68 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 832/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.13 | Remaining:00:00.62 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 848/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.19 | Remaining:00:00.56 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 864/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.25 | Remaining:00:00.51 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 880/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.31 | Remaining:00:00.45 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 896/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.37 | Remaining:00:00.39 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 912/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.43 | Remaining:00:00.34 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 928/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.49 | Remaining:00:00.28 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 944/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.54 | Remaining:00:00.22 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 960/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.60 | Remaining:00:00.17 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 976/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.66 | Remaining:00:00.11 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 992/1024
# Fra:1 Mem:587.89M (Peak 595.80M) | Time:00:05.71 | Remaining:00:00.05 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 1008/1024
# Fra:1 Mem:591.41M (Peak 598.44M) | Time:00:05.78 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Sample 1024/1024
# Fra:1 Mem:591.41M (Peak 598.44M) | Time:00:05.78 | Mem:94.93M, Peak:102.84M | Scene, ViewLayer | Finished
# Saved: '/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp/temp_img.png'
# Time: 00:06.78 (Saving: 00:00.03)

# %%
# move wineglass on table
put_small_obj_over_big_obj( wineglass, table )

# %%
info_matrix = solve_xy_on_flat_surface( wineglass, table, dataset_path, scene_id )

# %%
info_matrix[0][0]
info_matrix[5][5]
# Out:
# (8, True, 6, True)

# %% [markdown]
# V2 Way of Finding Top Plane

# %%
dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94"
scene_id = "1420624e"

# open blender scene
blender_scene_path = os.path.join( dataset_path, scene_id, "fine", "scene.blend" )
bpy.ops.wm.open_mainfile(filepath = blender_scene_path)
print(flush=True)
config_GPU_and_render_quality()

# GOAL: Move microwave glass to oven
oven_name = "OvenFactory(2033892).spawn_asset(8574077)"
microwave_name = "MicrowaveFactory(1849906).spawn_asset(842634)"
oven = bpy.data.objects[oven_name]
microwave = bpy.data.objects[microwave_name]
# Out:
# Read blend: "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94/1420624e/fine/scene.blend"
#
# Scene name: Scene
# Engine      : CYCLES
# Backend     : CUDA
# Scene device: GPU
# Available devices:
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - Intel Xeon Gold 5320 CPU @ 2.20GHz type=CPU  use=False
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True

# %%
put_small_obj_over_big_obj( microwave, oven )

# %%
# degugging
def make_plane( corners ):
    # 1) Your four corner coordinates (order them consistently—here: bottom‑left, bottom‑right, top‑right, top‑left)
#    corners = [
#        Vector((-1.0, -1.0, 0.0)),  # v0
#        Vector(( 1.0, -1.0, 0.0)),  # v1
#        Vector(( 1.0,  1.0, 0.0)),  # v2
#        Vector((-1.0,  1.0, 0.0)),  # v3
#    ]

    # 2) One face that uses those verts in order
    faces = [(0, 1, 2, 3)]

    # 3) Create a new mesh datablock and fill it
    mesh = bpy.data.meshes.new(name="MyPlaneMesh")
    mesh.from_pydata(corners, [], faces)
    mesh.update()

    # 4) Create an object that uses this mesh
    obj = bpy.data.objects.new("MyPlane", mesh)

    # 5) Link the object into the current collection / scene
    col = bpy.context.collection
    col.objects.link(obj)

    # 6) (Optional) make it active and select it
    bpy.context.view_layer.objects.active = obj
    obj.select_set(True)

oven_mmD = max_min_bound_box( oven )
hits = raycast_top_grid( oven, oven_mmD["x_min"], oven_mmD["x_max"], oven_mmD["y_min"], oven_mmD["y_max"], oven_mmD["z_max"] )
top_plane = find_top_plane( hits )
x_min, x_max, y_min, y_max, z_median = top_plane
corners = [
    Vector((x_min, y_min, z_median)),
    Vector((x_max, y_min, z_median)),
    Vector((x_max, y_max, z_median)),
    Vector((x_min, y_max, z_median))
]
make_plane(corners)

# %%
# orient the mircowave
align_small_object_with_parenting( oven, microwave )

# get oven bound_box
oven_mmD = max_min_bound_box( oven )

# raycast to get hit vertices
hits = raycast_top_grid( oven, oven_mmD["x_min"], oven_mmD["x_max"], oven_mmD["y_min"], oven_mmD["y_max"], oven_mmD["z_max"] )

# convert collection of vectices to a plane (5-tuple)
top_plane = find_top_plane( hits )

# get info maxtrix using solver
info_matrix = solve_xy_on_flat_surface( microwave, oven, top_plane, dataset_path, scene_id )
# Out:
# ---------------------------------------------------------------------------
# ReferenceError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 # orient the mircowave
# ----> 2 align_small_object_with_parenting( oven, microwave )
#       4 # get oven bound_box
#       5 oven_mmD = max_min_bound_box( oven )
#
# Cell In[7], line 118, in align_small_object_with_parenting(parent, child)
#     115 def align_small_object_with_parenting( parent, child ):
#     116     """ Used to have child's axis line up with parent's axis
#     117      Front is +X in infinigen """
# --> 118     child.parent = parent
#     120     # zero out child transforms
#     121     child.matrix_basis.identity()
#
# ReferenceError: StructRNA of type Object has been removed

# %%
info_matrix
# Out:
# [[(3, True, 7, False),
#   (4, True, 7, False),
#   (4, True, 6, False),
#   (5, True, 7, False),
#   (6, True, 6, False),
#   (6, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 7, False)],
#  [(4, True, 7, False),
#   (4, True, 7, False),
#   (4, True, 6, False),
#   (6, True, 6, False),
#   (6, True, 6, False),
#   (6, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 7, False)],
#  [(4, True, 7, False),
#   (4, True, 7, False),
#   (4, True, 7, False),
#   (6, True, 7, False),
#   (6, True, 6, False),
#   (7, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 7, False)],
#  [(4, True, 7, False),
#   (4, True, 7, False),
#   (6, True, 7, False),
#   (6, True, 7, False),
#   (6, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 7, False)],
#  [(4, True, 7, False),
#   (4, True, 7, False),
#   (6, True, 6, False),
#   (6, True, 6, False),
#   (6, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 7, False)],
#  [(4, True, 7, False),
#   (4, True, 7, False),
#   (6, True, 5, False),
#   (6, True, 7, False),
#   (7, True, 5, False),
#   (8, True, 4, False),
#   (8, True, 5, False),
#   (8, True, 6, False),
#   (8, True, 5, False),
#   (8, True, 6, False),
#   (8, True, 7, False)],
#  [(4, True, 7, False),
#   (6, True, 7, False),
#   (6, True, 6, False),
#   (6, True, 7, False),
#   (8, True, 5, False),
#   (8, True, 4, False),
#   (8, True, 5, False),
#   (8, True, 6, False),
#   (8, True, 5, False),
#   (8, True, 6, False),
#   (8, True, 7, False)],
#  [(4, True, 7, False),
#   (6, True, 7, False),
#   (6, True, 7, False),
#   (6, True, 7, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 7, False)],
#  [(5, True, 7, False),
#   (6, True, 7, False),
#   (6, True, 6, False),
#   (7, True, 7, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 6, False),
#   (8, True, 5, False),
#   (8, True, 6, False),
#   (8, True, 7, False)],
#  [(6, True, 6, False),
#   (6, True, 6, False),
#   (6, True, 5, False),
#   (8, True, 5, False),
#   (8, True, 5, False),
#   (8, True, 4, False),
#   (8, True, 5, False),
#   (8, True, 5, False),
#   (8, True, 5, False),
#   (8, True, 6, False),
#   (8, True, 6, False)],
#  [(6, True, 4, False),
#   (6, True, 4, False),
#   (6, True, 4, False),
#   (8, True, 4, False),
#   (8, True, 4, False),
#   (8, True, 4, False),
#   (8, True, 4, False),
#   (8, True, 4, False),
#   (8, True, 4, False),
#   (8, True, 4, False),
#   (8, True, 4, False)]]

# %% [markdown]
# specfic modification for kitchenSpace (finding the lower counter top)

# %%
dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94"
scene_id = "2dbefffc"

# open blender scene
blender_scene_path = os.path.join( dataset_path, scene_id, "fine", "scene.blend" )
bpy.ops.wm.open_mainfile(filepath = blender_scene_path)
print(flush=True)
config_GPU_and_render_quality()

# GOAL: Move wine glass to table
plant_name = "LargePlantContainerFactory(949299).spawn_asset(2608831)"
kitchenSpace_name = "KitchenSpaceFactory(3989955).spawn_asset(8637063)"
plant = bpy.data.objects[plant_name]
kitchenSpace = bpy.data.objects[kitchenSpace_name]
# Out:
# Read blend: "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94/2dbefffc/fine/scene.blend"
#
# Scene name: Scene
# Engine      : CYCLES
# Backend     : CUDA
# Scene device: GPU
# Available devices:
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - Intel Xeon Gold 5320 CPU @ 2.20GHz type=CPU  use=False
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True

# %%
# orient the plant
align_small_object_with_parenting( kitchenSpace, plant )

# get kitchenSpace bound_box
kitchenSpace_mmD = max_min_bound_box( kitchenSpace )

# SPECIAL: Update kitchenSpace upper bound box to only include bottom counter
max_gap, max_pair = largest_z_gap( kitchenSpace )
kitchenSpace_mmD["z_max"] = ( max_pair[0] + max_pair[1] ) / 2

# raycast to get hit vertices
hits = raycast_top_grid( kitchenSpace, kitchenSpace_mmD["x_min"], kitchenSpace_mmD["x_max"], 
                        kitchenSpace_mmD["y_min"], kitchenSpace_mmD["y_max"], kitchenSpace_mmD["z_max"] )

# convert collection of vectices to a plane (5-tuple)
top_plane = find_top_plane( hits )

# get info maxtrix using solver
info_matrix = solve_xy_on_flat_surface( plant, kitchenSpace, top_plane, dataset_path, scene_id )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # orient the plant
# ----> 2 align_small_object_with_parenting( kitchenSpace, plant )
#       4 # get kitchenSpace bound_box
#       5 kitchenSpace_mmD = max_min_bound_box( kitchenSpace )
#
# NameError: name 'kitchenSpace' is not defined

# %% [markdown]
# Testing Best Object Alignment

# %%
# dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94"
# scene_id = "2dbefffc"

# # open blender scene
# blender_scene_path = os.path.join( dataset_path, scene_id, "fine", "scene.blend" )
# bpy.ops.wm.open_mainfile(filepath = blender_scene_path)
# print(flush=True)
# config_GPU_and_render_quality()

# # GOAL: Move wine glass to table
# small_obj_name = "LargePlantContainerFactory(949299).spawn_asset(2608831)"
# big_obj_name = "KitchenSpaceFactory(3989955).spawn_asset(8637063)"
# small_obj = bpy.data.objects[small_obj_name]
# big_obj = bpy.data.objects[big_obj_name]

# dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94"
# scene_id = "1420624e"


# # open blender scene
# blender_scene_path = os.path.join( dataset_path, scene_id, "fine", "scene.blend" )
# bpy.ops.wm.open_mainfile(filepath = blender_scene_path)
# print(flush=True)
# config_GPU_and_render_quality()

# # GOAL: Move microwave glass to oven
# big_obj_name = "OvenFactory(2033892).spawn_asset(8574077)"
# small_obj_name = "MicrowaveFactory(1849906).spawn_asset(842634)"
# big_obj = bpy.data.objects[big_obj_name]
# small_obj = bpy.data.objects[small_obj_name]


dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94"
scene_id = "2c653f74"

# open blender scene
blender_scene_path = os.path.join( dataset_path, scene_id, "fine", "scene.blend" )
bpy.ops.wm.open_mainfile(filepath = blender_scene_path)
print(flush=True)
config_GPU_and_render_quality()

# GOAL: Move microwave glass to oven
big_obj_name = "LargeShelfFactory(2741555).spawn_asset(1952064)"
small_obj_name = "BottleFactory(1493237).spawn_asset(8652564)"
big_obj = bpy.data.objects[big_obj_name]
small_obj = bpy.data.objects[small_obj_name]
# Out:
# Read blend: "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94/2c653f74/fine/scene.blend"
#
# Scene name: Scene
# Engine      : CYCLES
# Backend     : CUDA
# Scene device: GPU
# Available devices:
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - Intel Xeon Gold 5320 CPU @ 2.20GHz type=CPU  use=False
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True

# %%
# orient the small_obj
align_small_object_with_parenting( big_obj, small_obj )

# get kitchenSpace bound_box
big_mmD = max_min_bound_box( big_obj )

# SPECIAL: Update kitchenSpace upper bound box to only include bottom counter
if "KitchenSpace" in big_obj.name:
    max_gap, max_pair = largest_z_gap( big_obj )
    big_mmD["z_max"] = ( max_pair[0] + max_pair[1] ) / 2

# raycast to get hit vertices
hits = raycast_top_grid( big_obj, big_mmD["x_min"], big_mmD["x_max"], 
                        big_mmD["y_min"], big_mmD["y_max"], big_mmD["z_max"] )

# convert collection of vectices to a plane (5-tuple)
top_plane = find_top_plane( hits )

# get info maxtrix using solver
info_matrix = solve_xy_on_flat_surface( small_obj, big_obj, top_plane, dataset_path, scene_id )

# using info matrix place small object in the best location
score_list, best_tuple = put_object_in_best_loc( small_obj, info_matrix )

# %%
score_list
best_tuple
# score_list[5*11 + 5]
# info_matrix[5][5]
# info_matrix[9][2]
# Out:
# (1, 9, 2654.5454545454545)

# %% [markdown]
# # Export Room

# %%
dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/kitchenDataset94"
# scene_id = "1e122544"
# scene_id = "1420624e"
scene_id = "55ea34ab" # debug this

# SlideShow Image
dataset_path = "/n/fs/obj-cv/infinigen_project/Backups/CopyBackups/BatchTest1/my_dataset"
scene_id = "112d1667"

# dining room image
dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/diningRoom99"
scene_id = "7f9ecccd"

# bathroom image
dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/bathroom97"
scene_id = "169a7ea3"

# bedroom image
dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/bedroom96"
scene_id = "17349b62"
scene_id = "12fd0dc7" # simple book case

# livingroom image
dataset_path = "/n/fs/obj-cv/infinigen_project/savedDatasets/livingRoom99"
scene_id = "103ade0b"
scene_id = "167b03df"
scene_id = "1801d554"

# open blender scene
blender_scene_path = os.path.join( dataset_path, scene_id, "fine", "scene.blend" )
bpy.ops.wm.open_mainfile(filepath = blender_scene_path)
print(flush=True)
config_GPU_and_render_quality()

# open object.json
obj_json_path = os.path.join( dataset_path, scene_id, "frames", "Objects", "camera_0", "Objects_0_0_0048_0.json")
with open( obj_json_path, "r") as obj_json_file:
    obj_json_map = json.load(obj_json_file)

# GOAL: Delete everything that is not present in objects json
all_objs = list( bpy.data.objects )
for obj in all_objs:
    if obj.name not in obj_json_map.keys():
        bpy.data.objects.remove(obj, do_unlink=True)
# if you want to clear all orphaned data (might want to keep parents though)
# bpy.ops.outliner.orphans_purge(do_local_ids=True, do_linked_ids=True, do_recursive=True)

bpy.ops.wm.save_as_mainfile(
    filepath="/n/fs/obj-cv/experiment_project/experiments/objectSwapRelationshipExp/new_scene.blend",
    check_existing=True,    # prompt or overwrite if it already exists
    compress=True           # write with built‑in compression
)
# Out:
# Read blend: "/n/fs/obj-cv/infinigen_project/savedDatasets/livingRoom99/1801d554/fine/scene.blend"
#
# Scene name: Scene
# Engine      : CYCLES
# Backend     : CUDA
# Scene device: GPU
# Available devices:
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - NVIDIA L40                type=CUDA use=True
#   - Intel Xeon Gold 5320 CPU @ 2.20GHz type=CPU  use=False
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
#   - NVIDIA L40                type=OPTIX use=True
# Info: Saved "new_scene.blend"
# {'FINISHED'}
